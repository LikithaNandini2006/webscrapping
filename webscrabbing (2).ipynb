# %%
import requests
# !pip install beautifulsoup4
from bs4 import BeautifulSoup

# %%
Url="https://www.flipkart.com/search?q=watches&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

# %%
page = requests.get(Url)

# %%
page
# Out:
# <Response [200]>

# %%
page.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.aa1465.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/bundle.fbaef9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="app
# ...

# %%
brand = []
price_data = []
discount_data=[]
availability_data=[]
name_data=[]
pages = 40

# %%
url1 = "https://www.flipkart.com/search?q=watches&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1"

# %%
headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36 Edg/144.0.0.0"
}

# %%
url = url1
page = requests.get(url,headers = headers)
soup = BeautifulSoup(page.text)

# %%
page
# Out:
# <Response [200]>

# %%
import re
import numpy as np

# %%
soup.find_all("a", class_="atJtCj")
# Out:
# [<a class="atJtCj" href="/shivark-analog-watch-boys/p/itm2ab544b831fd1?pid=WATHBDS5RCZPXSDK&amp;lid=LSTWATHBDS5RCZPXSDK7BJK2T&amp;marketplace=FLIPKART&amp;q=watches&amp;store=r18&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_GtM6xyzfKfh_sCfy5ZWn5vfpqChLqFo1ef4laXx4co4zJs5Fg8fbyOH_-Eon_V_2mUNtZuixsgYyg5KJ5DEhXQ%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=qu1w4vdw740000001769057560757&amp;qH=2d6b6aad43dffa91" rel="noopener noreferrer" target="_blank" title="Analog Watch  - For Boys New Attractive Designer Blue Dial Watch and King Bracelet Combo">Analog Watch  - For Boys New Attractive Designer Blue D...</a>,
# ...

# %%
brand=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    regex=re.findall("^[a-zA-Z]+",i.text)
    print(regex)
    if regex:
        brand.append(regex[0])
    else:
        brand.append(np.nan)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# ['Analog']
# Silicone Strap Boys Analog Watch  - For Men SL-01
# ['Silicone']
# Men's and Women's Watch Box Holder Organizer Case in Bl...
# ['Men']
# Digital Watch - For Boys & Girls digital watch kids sil...
# ['Digital']
# Premium Faux Leather Wrist Organiser Watch Box (Black, ...
# ['Premium']
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# ['Analog']
# Velvet box Watch Box
# ['Velvet']
# Vanshika Enterprises Stainless Steel Metal 22mm Compati...
# ['Vanshika']
# Analog Watch  - For Men DR20 Series
# ['Analog']
# Digital Watch  - For Boys & Girls 8517
# ['Digital']
# Analog Watch  - For Men New Stylish Combo Of Silver Ave...
# ['Analog']
# PREMBROTHERS Heavy Metal Chain with Secure Lock Technol...
# ['PREMBROTHERS']
# Men's and Women's Watch Box Holder Organizer Case in Bl...
# ['Men']
# Travel Watch Case Organizer Watch Box With Zipper Heavy...
# ['Travel']
# Bharasoft HUB LOCK 1-piece Watch Repair Kit
# ...

# %%
# soup.find("div", class_="Nx9bqj").text
price=[]
for i in soup("div",class_="hZ3P6w"):
    print(i.text)
    price.append(i.text)
# Out:
# ₹187
# ₹170
# ₹399
# ₹219
# ₹616
# ₹166
# ₹198
# ₹289
# ₹279
# ₹375
# ₹187
# ₹240
# ₹404
# ₹466
# ₹265
# ₹349
# ₹7,439
# ₹263
# ₹405
# ₹579
# ₹260
# ₹237
# ₹579
# ₹174
# ₹781
# ₹599
# ₹263
# ₹166
# ₹179
# ₹260
# ₹192
# ₹231
# ₹261
# ₹639
# ₹279
# ₹345
# ₹267
# ₹10,559
# ₹548
# ₹406
# ₹345
# ₹579
# ₹166
# ₹404
# ₹240

# %%
# soup.find("div", class_="XQDdHH").text
discount=[]
for i in soup.find_all("div",class_="HQe8jr"):
    print(i.text)
    discount.append(i.text)
# Out:
# 81% off
# 82% off
# 88% off
# 78% off
# 87% off
# 83% off
# 80% off
# 63% off
# 72% off
# 87% off
# 85% off
# 81% off
# 82% off
# 48% off
# 73% off
# 73% off
# 40% off
# 86% off
# 54% off
# 61% off
# 86% off
# 88% off
# 55% off
# 82% off
# 76% off
# 64% off
# 73% off
# 83% off
# 82% off
# 62% off
# 61% off
# 84% off
# 85% off
# 46% off
# 85% off
# 88% off
# 86% off
# 20% off
# 8% off
# 59% off
# 88% off
# 61% off
# 83% off
# 82% off
# 81% off

# %%
# soup.find("div", class_="XQDdHH").text
availability=[]
for i in soup.find_all("div",class_="HZ0E6r Rm9_cy"):
    print(i.text)
    availability.append(i.text)
# Out:
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Only few left
# Top Discount of the Sale
# Only few left
# Only few left
# Only few left
# Only few left
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Only 1 left
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Only few left
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Only few left
# Only 3 left
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Only few left
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer
# Only few left
# Only few left
# Top Discount of the Sale
# Bank Offer
# Only few left
# Only few left

# %%
name=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    name.append(i.text)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# Silicone Strap Boys Analog Watch  - For Men SL-01
# Men's and Women's Watch Box Holder Organizer Case in Bl...
# Digital Watch - For Boys & Girls digital watch kids sil...
# Premium Faux Leather Wrist Organiser Watch Box (Black, ...
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# Velvet box Watch Box
# Vanshika Enterprises Stainless Steel Metal 22mm Compati...
# Analog Watch  - For Men DR20 Series
# Digital Watch  - For Boys & Girls 8517
# Analog Watch  - For Men New Stylish Combo Of Silver Ave...
# PREMBROTHERS Heavy Metal Chain with Secure Lock Technol...
# Men's and Women's Watch Box Holder Organizer Case in Bl...
# Travel Watch Case Organizer Watch Box With Zipper Heavy...
# Bharasoft HUB LOCK 1-piece Watch Repair Kit
# Silver Dial Analog Watch  - For Women TWTL10104
# EVERETT Analog Watch  - For Men 2011310
# Elegant Series Square Quartz For /Boys Wrist Analog Wat...
# ...

# %%
len(brand)
# Out:
# 40

# %%
price = price[:40]

# %%
discount=discount[:40]

# %%
name=name[:40]

# %%
availability=availability[:40]

# %%
# phones={"Brand":brand,"Color":color,"Storage":storage,"Rating":rating,"Screen_size":sreen_size,"Battery":battery,"Price":price}

b1= {"Brand": brand, "Price":price,"Discount":discount,"Availability":availability,"Name":name}

# %%
b1
# Out:
# {'Brand': ['Analog',
#   'Silicone',
#   'Men',
#   'Digital',
#   'Premium',
#   'Analog',
#   'Velvet',
#   'Vanshika',
#   'Analog',
#   'Digital',
#   'Analog',
#   'PREMBROTHERS',
#   'Men',
#   'Travel',
#   'Bharasoft',
#   'Silver',
#   'EVERETT',
#   'Elegant',
#   'Travel',
#   'Round',
#   'Day',
#   'Minimalist',
#   'Pink',
#   'Silicone',
#   'Analog',
#   'Crysendo',
#   'Trending',
#   'Analog',
#   'SP',
#   'Jouet',
#   'Digital',
#   'EVR',
#   'Rose',
#   'Faux',
#   'Professional',
#   'Car',
#   'Avatar',
#   'Analog',
#   'Hot',
#   'T'],
#  'Price': ['₹187',
#   '₹170',
#   '₹399',
#   '₹219',
#   '₹616',
#   '₹166',
#   '₹198',
#   '₹289',
#   '₹279',
#   '₹375',
#   '₹187',
#   '₹240',
#   '₹404',
#   '₹466',
#   '₹265',
#   '₹349',
#   '₹7,439',
#   '₹263',
#   '₹405',
#   '₹579',
#   '₹260',
#   '₹237',
#   '₹579',
#   '₹174',
#   '₹781',
#   '₹599',
#   '₹263',
#   '₹166',
#   '₹179',
#   '₹260',
#   '₹192',
#   '₹231',
#   '₹261',
#   '₹639',
# ...

# %%
import pandas as pd
b1 = pd.DataFrame(b1)

# %%
b1
# Out:
#            Brand    Price Discount              Availability  \
# 0         Analog     ₹187  81% off  Top Discount of the Sale
# 1       Silicone     ₹170  82% off  Top Discount of the Sale
# 2            Men     ₹399  88% off  Top Discount of the Sale
# 3        Digital     ₹219  78% off             Only few left
# 4        Premium     ₹616  87% off             Only few left
# 5         Analog     ₹166  83% off  Top Discount of the Sale
# 6         Velvet     ₹198  80% off             Only few left
# 7       Vanshika     ₹289  63% off             Only few left
# 8         Analog     ₹279  72% off             Only few left
# 9        Digital     ₹375  87% off             Only few left
# 10        Analog     ₹187  85% off  Top Discount of the Sale
# 11  PREMBROTHERS     ₹240  81% off                Bank Offer
# 12           Men     ₹404  82% off  Top Discount of the Sale
# 13        Travel     ₹466  48% off               Only 1 left
# ...

# %%
url2="https://www.flipkart.com/search?q=watches&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&sort=relevance&page=2"

# %%
url = url2
page = requests.get(url,headers = headers)
soup = BeautifulSoup(page.text)

# %%
page
# Out:
# <Response [200]>

# %%
import re
import numpy as np

# %%
soup.find_all("a", class_="atJtCj")
# Out:
# [<a class="atJtCj" href="/shivark-analog-watch-boys/p/itm2ab544b831fd1?pid=WATHBDS5RCZPXSDK&amp;lid=LSTWATHBDS5RCZPXSDK7BJK2T&amp;marketplace=FLIPKART&amp;q=watches&amp;store=r18&amp;srno=s_2_41&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_8YxdiN2NY8q5dBr4J-YvPFT0xDt6gM3S3ecGqRj7EQF0ENFFdEW49mzLhoMGzYkIrSrC5iHEVgUT8tylfs2KbA%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=qbdue9v54g0000001769059692052&amp;qH=2d6b6aad43dffa91" rel="noopener noreferrer" target="_blank" title="Analog Watch  - For Boys New Attractive Designer Blue Dial Watch and King Bracelet Combo">Analog Watch  - For Boys New Attractive Designer Blue D...</a>,
# ...

# %%
brand=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    regex=re.findall("^[a-zA-Z]+",i.text)
    print(regex)
    if regex:
        brand.append(regex[0])
    else:
        brand.append(np.nan)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# ['Analog']
# Analog Watch  - For Men PZ626
# ['Analog']
# Analog Watch  - For Women VH000008C
# ['Analog']
# Arabic Sunshine Dial Casual Ultra Thin Fashion Stainles...
# ['Arabic']
# The Mystic Curve Analog Watch  - For Women FCN0110NRTM
# ['The']
# Men's Analog Silver Watch | Dated Blue Sunray Round Dia...
# ['Men']
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# ['Analog']
# Analog Watch  - For Men New Stylish Combo Of Silver Ave...
# ['Analog']
# Analog Watch  - For Men AS000010E
# ['Analog']
# Hot Sale Business Men Quart Watches Luxury Waterproof S...
# ['Hot']
# Branded Bracelet | Gold Plated | Studded | 3D Cut Glass...
# ['Branded']
# Analog Watch  - For Men DK11125-5
# ['Analog']
# REESE Analog Watch  - For Women VH000026E_
# ['REESE']
# Analog Watch  - For Men PE000016B
# ['Analog']
# Analog Watch  - For Women AMWW431
# ['Analog']
# ANALOG WATCHES Analog Watch  - For Men & Women CLASSIC ...
# ['ANALOG']
# ...

# %%
# soup.find("div", class_="Nx9bqj").text
price=[]
for i in soup("div",class_="hZ3P6w"):
    print(i.text)
    price.append(i.text)
# Out:
# ₹187
# ₹192
# ₹1,439
# ₹548
# ₹2,639
# ₹2,689
# ₹166
# ₹187
# ₹1,289
# ₹548
# ₹322
# ₹2,019
# ₹1,539
# ₹649
# ₹759
# ₹548
# ₹3,145
# ₹264
# ₹255
# ₹255
# ₹166
# ₹237
# ₹1,169
# ₹315
# ₹8,899
# ₹14,495
# ₹192
# ₹231
# ₹269
# ₹548
# ₹448
# ₹2,279
# ₹250
# ₹1,129
# ₹639
# ₹548
# ₹299
# ₹255
# ₹1,535
# ₹6,749
# ₹255
# ₹3,145
# ₹8,899
# ₹299
# ₹1,169

# %%
# soup.find("div", class_="XQDdHH").text
discount=[]
for i in soup.find_all("div",class_="HQe8jr"):
    print(i.text)
    discount.append(i.text)
# Out:
# 81% off
# 85% off
# 52% off
# 8% off
# 83% off
# 61% off
# 83% off
# 85% off
# 55% off
# 8% off
# 89% off
# 81% off
# 67% off
# 61% off
# 80% off
# 8% off
# 10% off
# 86% off
# 74% off
# 78% off
# 83% off
# 88% off
# 54% off
# 89% off
# 63% off
# 61% off
# 84% off
# 87% off
# 8% off
# 77% off
# 73% off
# 89% off
# 76% off
# 57% off
# 8% off
# 88% off
# 84% off
# 40% off
# 61% off
# 74% off
# 10% off
# 63% off
# 88% off
# 54% off

# %%
# soup.find("div", class_="XQDdHH").text
availability=[]
for i in soup.find_all("div",class_="HZ0E6r Rm9_cy"):
    print(i.text)
    availability.append(i.text)
# Out:
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Only few left
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Only few left
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer
# Bank Offer
# Only few left
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Only few left
# Top Discount of the Sale
# Only few left
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Only few left
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Only 2 left
# Top Discount of the Sale
# Only few left
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer

# %%
name=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    name.append(i.text)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# Analog Watch  - For Men PZ626
# Analog Watch  - For Women VH000008C
# Arabic Sunshine Dial Casual Ultra Thin Fashion Stainles...
# The Mystic Curve Analog Watch  - For Women FCN0110NRTM
# Men's Analog Silver Watch | Dated Blue Sunray Round Dia...
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# Analog Watch  - For Men New Stylish Combo Of Silver Ave...
# Analog Watch  - For Men AS000010E
# Hot Sale Business Men Quart Watches Luxury Waterproof S...
# Branded Bracelet | Gold Plated | Studded | 3D Cut Glass...
# Analog Watch  - For Men DK11125-5
# REESE Analog Watch  - For Women VH000026E_
# Analog Watch  - For Men PE000016B
# Analog Watch  - For Women AMWW431
# ANALOG WATCHES Analog Watch  - For Men & Women CLASSIC ...
# VINTAGE Analog-Digital Watch  - For Men & Women AD279 (...
# Day And Date Functioning High Quality Combo Of King Pri...
# Aura black Analog Watch  - For Men Arabic Aura
# ...

# %%
len(brand)
# Out:
# 40

# %%
price = price[:40]
discount=discount[:40]
name=name[:40]
availability=availability[:40]

# %%
# phones={"Brand":brand,"Color":color,"Storage":storage,"Rating":rating,"Screen_size":sreen_size,"Battery":battery,"Price":price}

b2= {"Brand": brand, "Price":price,"Discount":discount,"Availability":availability,"Name":name}

# %%
b2
# Out:
# {'Brand': ['Analog',
#   'Analog',
#   'Analog',
#   'Arabic',
#   'The',
#   'Men',
#   'Analog',
#   'Analog',
#   'Analog',
#   'Hot',
#   'Branded',
#   'Analog',
#   'REESE',
#   'Analog',
#   'Analog',
#   'ANALOG',
#   'VINTAGE',
#   'Day',
#   'Aura',
#   'Sabar',
#   'Analog',
#   'Minimalist',
#   'Analog',
#   'STYLISH',
#   'Analog',
#   'Marlin',
#   'Digital',
#   'EVR',
#   'Analog',
#   'Hot',
#   'Apex',
#   'Gold',
#   'Man',
#   'Analog',
#   'Silver',
#   'Hot',
#   'Original',
#   'NEW',
#   'Fastrack',
#   'Analog'],
#  'Price': ['₹187',
#   '₹192',
#   '₹1,439',
#   '₹548',
#   '₹2,639',
#   '₹2,689',
#   '₹166',
#   '₹187',
#   '₹1,289',
#   '₹548',
#   '₹322',
#   '₹2,019',
#   '₹1,539',
#   '₹649',
#   '₹759',
#   '₹548',
#   '₹3,145',
#   '₹264',
#   '₹255',
#   '₹255',
#   '₹166',
#   '₹237',
#   '₹1,169',
#   '₹315',
#   '₹8,899',
#   '₹14,495',
#   '₹192',
#   '₹231',
#   '₹269',
#   '₹548',
#   '₹448',
#   '₹2,279',
#   '₹250',
#   '₹1,129',
# ...

# %%
import pandas as pd
b2 = pd.DataFrame(b2)

# %%
b2
# Out:
#          Brand    Price Discount              Availability  \
# 0       Analog     ₹187  81% off  Top Discount of the Sale
# 1       Analog     ₹192  85% off  Top Discount of the Sale
# 2       Analog   ₹1,439  52% off                Bank Offer
# 3       Arabic     ₹548   8% off             Only few left
# 4          The   ₹2,639  83% off                Bank Offer
# 5          Men   ₹2,689  61% off                Bank Offer
# 6       Analog     ₹166  83% off  Top Discount of the Sale
# 7       Analog     ₹187  85% off  Top Discount of the Sale
# 8       Analog   ₹1,289  55% off                Bank Offer
# 9          Hot     ₹548   8% off             Only few left
# 10     Branded     ₹322  89% off  Top Discount of the Sale
# 11      Analog   ₹2,019  81% off                Bank Offer
# 12       REESE   ₹1,539  67% off                Bank Offer
# 13      Analog     ₹649  61% off                Bank Offer
# 14      Analog     ₹759  80% off                Bank Offer
# ...

# %%
url3="https://www.flipkart.com/search?q=watches&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&sort=relevance&page=3"

# %%
url = url3
page = requests.get(url,headers = headers)
soup = BeautifulSoup(page.text)

# %%
page
# Out:
# <Response [200]>

# %%
import re
import numpy as np

# %%
soup.find_all("a", class_="atJtCj")
# Out:
# [<a class="atJtCj" href="/shivark-analog-watch-boys/p/itm2ab544b831fd1?pid=WATHBDS5RCZPXSDK&amp;lid=LSTWATHBDS5RCZPXSDK7BJK2T&amp;marketplace=FLIPKART&amp;q=watches&amp;store=r18&amp;srno=s_3_81&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_x0gYYAaB4OGOnACEZH-yrvzrmRvmIfen-H25AYZEtpiBbSjf64vh8s_sR8tJ3Q03rSrC5iHEVgUT8tylfs2KbA%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=l3btbdwdkw0000001769060044854&amp;qH=2d6b6aad43dffa91" rel="noopener noreferrer" target="_blank" title="Analog Watch  - For Boys New Attractive Designer Blue Dial Watch and King Bracelet Combo">Analog Watch  - For Boys New Attractive Designer Blue D...</a>,
# ...

# %%
brand=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    regex=re.findall("^[a-zA-Z]+",i.text)
    print(regex)
    if regex:
        brand.append(regex[0])
    else:
        brand.append(np.nan)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# ['Analog']
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# ['Analog']
# Analog Watch  - For Men PE000028A
# ['Analog']
# Premium Analog Series Black Polycarbonate Plastic Strap...
# ['Premium']
# Minimalist Rose Gold Dial with Glossy Strap Analog Watc...
# ['Minimalist']
# Pattern Analog Watch  - For Women VH000028C
# ['Pattern']
# Analog Watch  - For Men New Stylish Combo Of Silver Ave...
# ['Analog']
# PREMBROTHERS Heavy Metal Chain with Secure Lock Technol...
# ['PREMBROTHERS']
# Date Functioning Genuine Quality Softest Silicon Strap ...
# ['Date']
# Vintage Black Dial Silver Stainless Steel Band Digital ...
# ['Vintage']
# T10 Ultra2 smartwatch with calling Hybrid Smartwatch Wa...
# ['T']
# Minimalist Series | Smart Watch Strap | Smart Clip | So...
# ['Minimalist']
# Fastrack Vyb Celeste Quartz Coffee Dial Coffee Brown SS...
# ['Fastrack']
# Black Dial Analog Watch  - For Men TW0TG7802
# ['Black']
# ...

# %%
# soup.find("div", class_="Nx9bqj").text
price=[]
for i in soup("div",class_="hZ3P6w"):
    print(i.text)
    price.append(i.text)
# Out:
# ₹187
# ₹166
# ₹989
# ₹460
# ₹382
# ₹1,229
# ₹187
# ₹240
# ₹255
# ₹1,994
# ₹393
# ₹269
# ₹1,280
# ₹609
# ₹164
# ₹859
# ₹228
# ₹2,399
# ₹5,479
# ₹1,019
# ₹263
# ₹260
# ₹171
# ₹1,409
# ₹744
# ₹182
# ₹113
# ₹166
# ₹1,269
# ₹1,695
# ₹237
# ₹192
# ₹659
# ₹7,465
# ₹1,309
# ₹251
# ₹2,279
# ₹448
# ₹413
# ₹179
# ₹989
# ₹382
# ₹659
# ₹1,019
# ₹228

# %%
# soup.find("div", class_="XQDdHH").text
discount=[]
for i in soup.find_all("div",class_="HQe8jr"):
    print(i.text)
    discount.append(i.text)
# Out:
# 81% off
# 83% off
# 59% off
# 84% off
# 83% off
# 63% off
# 85% off
# 81% off
# 74% off
# 89% off
# 87% off
# 40% off
# 60% off
# 83% off
# 57% off
# 89% off
# 48% off
# 38% off
# 39% off
# 86% off
# 86% off
# 80% off
# 45% off
# 4% off
# 81% off
# 71% off
# 83% off
# 70% off
# 15% off
# 88% off
# 61% off
# 55% off
# 10% off
# 40% off
# 74% off
# 73% off
# 77% off
# 89% off
# 74% off
# 59% off
# 83% off
# 55% off
# 39% off
# 89% off

# %%
# soup.find("div", class_="XQDdHH").text
availability=[]
for i in soup.find_all("div",class_="HZ0E6r Rm9_cy"):
    print(i.text)
    availability.append(i.text)
# Out:
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Only few left
# Only few left
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Only few left
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Only few left
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Bank Offer
# Only 3 left
# Only few left
# Bank Offer
# Top Discount of the Sale
# Only 1 left
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Bank Offer
# Only few left
# Bank Offer
# Bank Offer
# Only few left
# Only few left

# %%
name=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    name.append(i.text)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# Analog Watch  - For Men PE000028A
# Premium Analog Series Black Polycarbonate Plastic Strap...
# Minimalist Rose Gold Dial with Glossy Strap Analog Watc...
# Pattern Analog Watch  - For Women VH000028C
# Analog Watch  - For Men New Stylish Combo Of Silver Ave...
# PREMBROTHERS Heavy Metal Chain with Secure Lock Technol...
# Date Functioning Genuine Quality Softest Silicon Strap ...
# Vintage Black Dial Silver Stainless Steel Band Digital ...
# T10 Ultra2 smartwatch with calling Hybrid Smartwatch Wa...
# Minimalist Series | Smart Watch Strap | Smart Clip | So...
# Fastrack Vyb Celeste Quartz Coffee Dial Coffee Brown SS...
# Black Dial Analog Watch  - For Men TW0TG7802
# TRENDINGVIEW Genuine Watch Strap Band for Apple Watch S...
# Analog Watch  - For Men PE000008F
# Man Analog Watch  - For Men LD-BK0054-OCEAN Silicone St...
# ...

# %%
len(brand)
# Out:
# 40

# %%
price = price[:40]
discount=discount[:40]
name=name[:40]
availability=availability[:40]

# %%
# phones={"Brand":brand,"Color":color,"Storage":storage,"Rating":rating,"Screen_size":sreen_size,"Battery":battery,"Price":price}

b3= {"Brand": brand, "Price":price,"Discount":discount,"Availability":availability,"Name":name}

# %%
b3
# Out:
# {'Brand': ['Analog',
#   'Analog',
#   'Analog',
#   'Premium',
#   'Minimalist',
#   'Pattern',
#   'Analog',
#   'PREMBROTHERS',
#   'Date',
#   'Vintage',
#   'T',
#   'Minimalist',
#   'Fastrack',
#   'Black',
#   'TRENDINGVIEW',
#   'Analog',
#   'Man',
#   'Multifunction',
#   'Titan',
#   'Trendies',
#   'Elegant',
#   'Day',
#   'Men',
#   'Analog',
#   'Sonata',
#   'TRENDINGVIEW',
#   'Neupac',
#   'Analog',
#   'Analog',
#   'Titan',
#   'Minimalist',
#   'Digital',
#   'White',
#   'Fastrack',
#   'Fastrack',
#   'TRENDINGVIEW',
#   'Gold',
#   'Apex',
#   'T',
#   'TooHype'],
#  'Price': ['₹187',
#   '₹166',
#   '₹989',
#   '₹460',
#   '₹382',
#   '₹1,229',
#   '₹187',
#   '₹240',
#   '₹255',
#   '₹1,994',
#   '₹393',
#   '₹269',
#   '₹1,280',
#   '₹609',
#   '₹164',
#   '₹859',
#   '₹228',
#   '₹2,399',
#   '₹5,479',
#   '₹1,019',
#   '₹263',
#   '₹260',
#   '₹171',
#   '₹1,409',
#   '₹744',
#   '₹182',
#   '₹113',
#   '₹166',
#   '₹1,269',
#   '₹1,695',
#   '₹237',
# ...

# %%
import pandas as pd
b3 = pd.DataFrame(b3)

# %%
b3
# Out:
#             Brand   Price Discount              Availability  \
# 0          Analog    ₹187  81% off  Top Discount of the Sale
# 1          Analog    ₹166  83% off  Top Discount of the Sale
# 2          Analog    ₹989  59% off                Bank Offer
# 3         Premium    ₹460  84% off             Only few left
# 4      Minimalist    ₹382  83% off             Only few left
# 5         Pattern  ₹1,229  63% off                Bank Offer
# 6          Analog    ₹187  85% off  Top Discount of the Sale
# 7    PREMBROTHERS    ₹240  81% off                Bank Offer
# 8            Date    ₹255  74% off                Bank Offer
# 9         Vintage  ₹1,994  89% off             Only few left
# 10              T    ₹393  87% off  Top Discount of the Sale
# 11     Minimalist    ₹269  40% off  Top Discount of the Sale
# 12       Fastrack  ₹1,280  60% off  Top Discount of the Sale
# 13          Black    ₹609  83% off  Top Discount of the Sale
# ...

# %%
url4="https://www.flipkart.com/search?q=watches&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&sort=relevance&page=4"

# %%
url = url4
page = requests.get(url,headers = headers)
soup = BeautifulSoup(page.text)

# %%
page
# Out:
# <Response [200]>

# %%
import re
import numpy as np

# %%
soup.find_all("a", class_="atJtCj")
# Out:
# [<a class="atJtCj" href="/shivark-analog-watch-boys/p/itm2ab544b831fd1?pid=WATHBDS5RCZPXSDK&amp;lid=LSTWATHBDS5RCZPXSDK7BJK2T&amp;marketplace=FLIPKART&amp;q=watches&amp;store=r18&amp;srno=s_4_121&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_CJk5EH8LfEqzuvZR62_58WF6o6fU-W1v_mzayqU-HcunXcTVws1D6epgep7m5GXarSrC5iHEVgUT8tylfs2KbA%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=aqnrpwogu80000001769060285933&amp;qH=2d6b6aad43dffa91" rel="noopener noreferrer" target="_blank" title="Analog Watch  - For Boys New Attractive Designer Blue Dial Watch and King Bracelet Combo">Analog Watch  - For Boys New Attractive Designer Blue D...</a>,
# ...

# %%
brand=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    regex=re.findall("^[a-zA-Z]+",i.text)
    print(regex)
    if regex:
        brand.append(regex[0])
    else:
        brand.append(np.nan)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# ['Analog']
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# ['Analog']
# Bharasoft [HB] PREMIUM LEATHER STRAP FOR HUBLOT WATCHES...
# ['Bharasoft']
# Digital Watch - For Boys & Girls digital watch kids sil...
# ['Digital']
# Premium Faux Leather Wrist Organiser Watch Box (Black, ...
# ['Premium']
# Velvet box Watch Box
# ['Velvet']
# Analog Watch  - For Men New Stylish Combo Of Silver Ave...
# ['Analog']
# PREMBROTHERS Heavy Metal Chain with Secure Lock Technol...
# ['PREMBROTHERS']
# Travel Watch Case Organizer Watch Box With Zipper Heavy...
# ['Travel']
# Sonata Quartz Black Dial Black Plastic Strap Analog Wat...
# ['Sonata']
# T10 Ultra2 smartwatch with calling Hybrid Smartwatch Wa...
# ['T']
# Man Analog Watch  - For Men LD-BK0054-OCEAN Silicone St...
# ['Man']
# Titan Karishma Champagne Dial Golden Stainless Steel St...
# ['Titan']
# Analog Watch  - For Men AS000010G
# ['Analog']
# ...

# %%
# soup.find("div", class_="Nx9bqj").text
price=[]
for i in soup("div",class_="hZ3P6w"):
    print(i.text)
    price.append(i.text)
# Out:
# ₹187
# ₹166
# ₹488
# ₹219
# ₹616
# ₹198
# ₹187
# ₹240
# ₹405
# ₹809
# ₹393
# ₹228
# ₹1,994
# ₹809
# ₹599
# ₹423
# ₹269
# ₹2,399
# ₹226
# ₹289
# ₹263
# ₹260
# ₹1,539
# ₹748
# ₹1,109
# ₹406
# ₹166
# ₹113
# ₹579
# ₹398
# ₹237
# ₹192
# ₹2,803
# ₹171
# ₹16,635
# ₹398
# ₹2,279
# ₹448
# ₹859
# ₹383
# ₹1,994
# ₹748
# ₹809
# ₹228
# ₹226

# %%
# soup.find("div", class_="XQDdHH").text
discount=[]
for i in soup.find_all("div",class_="HQe8jr"):
    print(i.text)
    discount.append(i.text)
# Out:
# 81% off
# 83% off
# 75% off
# 78% off
# 87% off
# 80% off
# 85% off
# 81% off
# 54% off
# 89% off
# 89% off
# 75% off
# 64% off
# 82% off
# 87% off
# 48% off
# 84% off
# 63% off
# 86% off
# 86% off
# 43% off
# 67% off
# 59% off
# 83% off
# 71% off
# 55% off
# 84% off
# 88% off
# 61% off
# 10% off
# 80% off
# 20% off
# 84% off
# 73% off
# 77% off
# 57% off
# 61% off
# 75% off
# 89% off
# 84% off

# %%
# soup.find("div", class_="XQDdHH").text
availability=[]
for i in soup.find_all("div",class_="HZ0E6r Rm9_cy"):
    print(i.text)
    availability.append(i.text)
# Out:
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Only few left
# Only few left
# Only few left
# Top Discount of the Sale
# Bank Offer
# Only few left
# Only 3 left
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Only 3 left
# Only few left
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Only few left
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Only few left
# Top Discount of the Sale
# Top Discount of the Sale
# Only 1 left
# Only few left
# Bank Offer
# Only few left
# Bank Offer
# Bank Offer
# Bank Offer
# Only few left

# %%
name=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    name.append(i.text)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# Bharasoft [HB] PREMIUM LEATHER STRAP FOR HUBLOT WATCHES...
# Digital Watch - For Boys & Girls digital watch kids sil...
# Premium Faux Leather Wrist Organiser Watch Box (Black, ...
# Velvet box Watch Box
# Analog Watch  - For Men New Stylish Combo Of Silver Ave...
# PREMBROTHERS Heavy Metal Chain with Secure Lock Technol...
# Travel Watch Case Organizer Watch Box With Zipper Heavy...
# Sonata Quartz Black Dial Black Plastic Strap Analog Wat...
# T10 Ultra2 smartwatch with calling Hybrid Smartwatch Wa...
# Man Analog Watch  - For Men LD-BK0054-OCEAN Silicone St...
# Titan Karishma Champagne Dial Golden Stainless Steel St...
# Analog Watch  - For Men AS000010G
# Crysendo Nylon Strap Compatible with AppleWatch Series ...
# SS-WB1-05-PKMH-3 Watch Box
# Minimalist Series | Smart Watch Strap | Smart Clip | So...
# Multifunction Black Dial Analog Watch  - For Men TW000T...
# ...

# %%
len(brand)
# Out:
# 40

# %%
price = price[:40]
discount=discount[:40]
name=name[:40]
availability=availability[:40]

# %%
# phones={"Brand":brand,"Color":color,"Storage":storage,"Rating":rating,"Screen_size":sreen_size,"Battery":battery,"Price":price}

b4= {"Brand": brand, "Price":price,"Discount":discount,"Availability":availability,"Name":name}

# %%
b4
# Out:
# {'Brand': ['Analog',
#   'Analog',
#   'Bharasoft',
#   'Digital',
#   'Premium',
#   'Velvet',
#   'Analog',
#   'PREMBROTHERS',
#   'Travel',
#   'Sonata',
#   'T',
#   'Man',
#   'Titan',
#   'Analog',
#   'Crysendo',
#   'SS',
#   'Minimalist',
#   'Multifunction',
#   'EVR',
#   'Vanshika',
#   'Elegant',
#   'Day',
#   'Analog',
#   'Sonata',
#   'Analog',
#   'T',
#   'Analog',
#   'Neupac',
#   'Black',
#   'Matrix',
#   'Minimalist',
#   'Digital',
#   'Titan',
#   'Men',
#   'Titan',
#   'Date',
#   'Gold',
#   'Apex',
#   'Analog',
#   'Rayyn'],
#  'Price': ['₹187',
#   '₹166',
#   '₹488',
#   '₹219',
#   '₹616',
#   '₹198',
#   '₹187',
#   '₹240',
#   '₹405',
#   '₹809',
#   '₹393',
#   '₹228',
#   '₹1,994',
#   '₹809',
#   '₹599',
#   '₹423',
#   '₹269',
#   '₹2,399',
#   '₹226',
#   '₹289',
#   '₹263',
#   '₹260',
#   '₹1,539',
#   '₹748',
#   '₹1,109',
#   '₹406',
#   '₹166',
#   '₹113',
#   '₹579',
#   '₹398',
#   '₹237',
#   '₹192',
#   '₹2,803',
#   '₹171',
# ...

# %%
import pandas as pd
b4 = pd.DataFrame(b4)

# %%
b4
# Out:
#             Brand    Price Discount              Availability  \
# 0          Analog     ₹187  81% off  Top Discount of the Sale
# 1          Analog     ₹166  83% off  Top Discount of the Sale
# 2       Bharasoft     ₹488  75% off             Only few left
# 3         Digital     ₹219  78% off             Only few left
# 4         Premium     ₹616  87% off             Only few left
# 5          Velvet     ₹198  80% off             Only few left
# 6          Analog     ₹187  85% off  Top Discount of the Sale
# 7    PREMBROTHERS     ₹240  81% off                Bank Offer
# 8          Travel     ₹405  54% off             Only few left
# 9          Sonata     ₹809  89% off               Only 3 left
# 10              T     ₹393  89% off  Top Discount of the Sale
# 11            Man     ₹228  75% off  Top Discount of the Sale
# 12          Titan   ₹1,994  64% off                Bank Offer
# 13         Analog     ₹809  82% off                Bank Offer
# ...

# %%
url5="https://www.flipkart.com/search?q=watches&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&sort=relevance&page=5"

# %%
url = url5
page = requests.get(url,headers = headers)
soup = BeautifulSoup(page.text)

# %%
page
# Out:
# <Response [200]>

# %%
import re
import numpy as np

# %%
soup.find_all("a", class_="atJtCj")
# Out:
# [<a class="atJtCj" href="/shivark-analog-watch-boys/p/itm2ab544b831fd1?pid=WATHBDS5RCZPXSDK&amp;lid=LSTWATHBDS5RCZPXSDK7BJK2T&amp;marketplace=FLIPKART&amp;q=watches&amp;store=r18&amp;srno=s_5_161&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_zEVfJ77ktFZhQzL0_KE-0XzDLKulsccl-weQATMYPMOcaGT2X8TogbNmrsddDCwWrSrC5iHEVgUT8tylfs2KbA%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=jb78sqb9u80000001769060515879&amp;qH=2d6b6aad43dffa91" rel="noopener noreferrer" target="_blank" title="Analog Watch  - For Boys New Attractive Designer Blue Dial Watch and King Bracelet Combo">Analog Watch  - For Boys New Attractive Designer Blue D...</a>,
# ...

# %%
brand=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    regex=re.findall("^[a-zA-Z]+",i.text)
    print(regex)
    if regex:
        brand.append(regex[0])
    else:
        brand.append(np.nan)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# ['Analog']
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# ['Analog']
# T900 Digital Watch  - For Boys & Girls 1221
# ['T']
# Hot Sale Business Men Quart Watches Luxury Waterproof S...
# ['Hot']
# Analog Watch  - For Couple AS000019B
# ['Analog']
# Sabar Analog Watch  - For Men & Women Sabar watch for m...
# ['Sabar']
# Analog Watch  - For Men New Stylish Combo Of Silver Ave...
# ['Analog']
# PREMBROTHERS Heavy Metal Chain with Secure Lock Technol...
# ['PREMBROTHERS']
# Titan Workwear Dark Grey & Anthracite Dial Silver Metal...
# ['Titan']
# Arabic Sunshine Dial Casual Ultra Thin Fashion Stainles...
# ['Arabic']
# T10 Ultra2 smartwatch with calling Hybrid Smartwatch Wa...
# ['T']
# Multifunction Black Dial Analog Watch  - For Men TW000T...
# ['Multifunction']
# TRENDINGVIEW Genuine Watch Strap Band for Apple Watch S...
# ['TRENDINGVIEW']
# Women's 6 Slots Watch Box case organizer Leatherette Pi...
# ['Women']
# ...

# %%
# soup.find("div", class_="Nx9bqj").text
price=[]
for i in soup("div",class_="hZ3P6w"):
    print(i.text)
    price.append(i.text)
# Out:
# ₹187
# ₹166
# ₹413
# ₹548
# ₹2,089
# ₹255
# ₹187
# ₹240
# ₹2,667
# ₹548
# ₹393
# ₹2,399
# ₹164
# ₹466
# ₹541
# ₹548
# ₹228
# ₹269
# ₹8,860
# ₹3,963
# ₹263
# ₹260
# ₹2,039
# ₹315
# ₹619
# ₹593
# ₹237
# ₹113
# ₹2,289
# ₹548
# ₹166
# ₹192
# ₹2,939
# ₹1,939
# ₹676
# ₹548
# ₹2,279
# ₹448
# ₹435
# ₹919
# ₹1,939
# ₹2,667
# ₹228
# ₹113
# ₹2,089

# %%
# soup.find("div", class_="XQDdHH").text
discount=[]
for i in soup.find_all("div",class_="HQe8jr"):
    print(i.text)
    discount.append(i.text)
# Out:
# 81% off
# 83% off
# 89% off
# 8% off
# 63% off
# 78% off
# 85% off
# 81% off
# 20% off
# 8% off
# 89% off
# 48% off
# 83% off
# 68% off
# 86% off
# 8% off
# 89% off
# 87% off
# 25% off
# 25% off
# 86% off
# 86% off
# 48% off
# 89% off
# 73% off
# 82% off
# 88% off
# 71% off
# 49% off
# 8% off
# 83% off
# 61% off
# 20% off
# 66% off
# 47% off
# 8% off
# 73% off
# 77% off
# 68% off
# 56% off
# 66% off
# 20% off
# 89% off
# 71% off
# 63% off

# %%
# soup.find("div", class_="XQDdHH").text
availability=[]
for i in soup.find_all("div",class_="HZ0E6r Rm9_cy"):
    print(i.text)
    availability.append(i.text)
# Out:
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Only few left
# Bank Offer
# Only few left
# Top Discount of the Sale
# Bank Offer
# Only few left
# Only few left
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Only 2 left
# Only few left
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Only few left
# Top Discount of the Sale
# Top Discount of the Sale
# Only 4 left
# Bank Offer
# Only few left
# Only few left
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer

# %%
name=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    name.append(i.text)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# T900 Digital Watch  - For Boys & Girls 1221
# Hot Sale Business Men Quart Watches Luxury Waterproof S...
# Analog Watch  - For Couple AS000019B
# Sabar Analog Watch  - For Men & Women Sabar watch for m...
# Analog Watch  - For Men New Stylish Combo Of Silver Ave...
# PREMBROTHERS Heavy Metal Chain with Secure Lock Technol...
# Titan Workwear Dark Grey & Anthracite Dial Silver Metal...
# Arabic Sunshine Dial Casual Ultra Thin Fashion Stainles...
# T10 Ultra2 smartwatch with calling Hybrid Smartwatch Wa...
# Multifunction Black Dial Analog Watch  - For Men TW000T...
# TRENDINGVIEW Genuine Watch Strap Band for Apple Watch S...
# Women's 6 Slots Watch Box case organizer Leatherette Pi...
# Men's and Women's Watch Box 12 Slots of watches Black &...
# ANALOG WATCHES Analog Watch  - For Men & Women CLASSIC ...
# Man Analog Watch  - For Men LD-BK0054-OCEAN Silicone St...
# ...

# %%
len(brand)
# Out:
# 40

# %%
price = price[:40]
discount=discount[:40]
name=name[:40]
availability=availability[:40]

# %%
# phones={"Brand":brand,"Color":color,"Storage":storage,"Rating":rating,"Screen_size":sreen_size,"Battery":battery,"Price":price}

b5= {"Brand": brand, "Price":price,"Discount":discount,"Availability":availability,"Name":name}

# %%
b5
# Out:
# {'Brand': ['Analog',
#   'Analog',
#   'T',
#   'Hot',
#   'Analog',
#   'Sabar',
#   'Analog',
#   'PREMBROTHERS',
#   'Titan',
#   'Arabic',
#   'T',
#   'Multifunction',
#   'TRENDINGVIEW',
#   'Women',
#   'Men',
#   'ANALOG',
#   'Man',
#   'Minimalist',
#   'Titan',
#   'Titan',
#   'Elegant',
#   'Day',
#   'Multifunction',
#   'STYLISH',
#   'Analog',
#   'Special',
#   'Minimalist',
#   'Neupac',
#   'Multifunction',
#   'Hot',
#   'Analog',
#   'Digital',
#   'Titan',
#   'Multi',
#   'Watch',
#   'Hot',
#   'Gold',
#   'Apex',
#   nan,
#   'Analog'],
#  'Price': ['₹187',
#   '₹166',
#   '₹413',
#   '₹548',
#   '₹2,089',
#   '₹255',
#   '₹187',
#   '₹240',
#   '₹2,667',
#   '₹548',
#   '₹393',
#   '₹2,399',
#   '₹164',
#   '₹466',
#   '₹541',
#   '₹548',
#   '₹228',
#   '₹269',
#   '₹8,860',
#   '₹3,963',
#   '₹263',
#   '₹260',
#   '₹2,039',
#   '₹315',
#   '₹619',
#   '₹593',
#   '₹237',
#   '₹113',
#   '₹2,289',
#   '₹548',
#   '₹166',
#   '₹192',
#   '₹2,939',
# ...

# %%
import pandas as pd
b5 = pd.DataFrame(b5)

# %%
b5
# Out:
#             Brand   Price Discount              Availability  \
# 0          Analog    ₹187  81% off  Top Discount of the Sale
# 1          Analog    ₹166  83% off  Top Discount of the Sale
# 2               T    ₹413  89% off             Only few left
# 3             Hot    ₹548   8% off             Only few left
# 4          Analog  ₹2,089  63% off                Bank Offer
# 5           Sabar    ₹255  78% off             Only few left
# 6          Analog    ₹187  85% off  Top Discount of the Sale
# 7    PREMBROTHERS    ₹240  81% off                Bank Offer
# 8           Titan  ₹2,667  20% off             Only few left
# 9          Arabic    ₹548   8% off             Only few left
# 10              T    ₹393  89% off  Top Discount of the Sale
# 11  Multifunction  ₹2,399  48% off  Top Discount of the Sale
# 12   TRENDINGVIEW    ₹164  83% off             Only few left
# 13          Women    ₹466  68% off  Top Discount of the Sale
# ...

# %%
url6="https://www.flipkart.com/search?q=watches&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&sort=relevance&page=6"

# %%
url = url1
page = requests.get(url,headers = headers)
soup = BeautifulSoup(page.text)

# %%
page
# Out:
# <Response [200]>

# %%
import re
import numpy as np

# %%
soup.find_all("a", class_="atJtCj")
# Out:
# [<a class="atJtCj" href="/shivark-analog-watch-boys/p/itm2ab544b831fd1?pid=WATHBDS5RCZPXSDK&amp;lid=LSTWATHBDS5RCZPXSDK7BJK2T&amp;marketplace=FLIPKART&amp;q=watches&amp;store=r18&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_GFUQVY8h5gxdCZxGRymxp2u4qyFfEQ_IeszuDu5KZkSxAE-slEq07_mzab43sQnsmUNtZuixsgYyg5KJ5DEhXQ%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=93qidavj9s0000001769060742178&amp;qH=2d6b6aad43dffa91" rel="noopener noreferrer" target="_blank" title="Analog Watch  - For Boys New Attractive Designer Blue Dial Watch and King Bracelet Combo">Analog Watch  - For Boys New Attractive Designer Blue D...</a>,
# ...

# %%
brand=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    regex=re.findall("^[a-zA-Z]+",i.text)
    print(regex)
    if regex:
        brand.append(regex[0])
    else:
        brand.append(np.nan)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# ['Analog']
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# ['Analog']
# Men's and Women's Watch Box Holder Organizer Case in Bl...
# ['Men']
# Luxury Serpent-Inspired Coil Watch with Crystal Encrust...
# ['Luxury']
# Velvet box Watch Box
# ['Velvet']
# PREMBROTHERS Heavy Metal Chain with Secure Lock Technol...
# ['PREMBROTHERS']
# Crysendo Nylon Strap Compatible with AppleWatch Series ...
# ['Crysendo']
# Hot Sale Business Men Quart Watches Luxury Waterproof S...
# ['Hot']
# Digital Watch  - For Boys & Girls 8517
# ['Digital']
# Men's and Women's Watch Box Holder Organizer Case in Bl...
# ['Men']
# T10 Ultra2 smartwatch with calling Hybrid Smartwatch Wa...
# ['T']
# Man Analog Watch  - For Men LD-BK0054-OCEAN Silicone St...
# ['Man']
# Silver Dial Analog Watch  - For Women TWTL10104
# ['Silver']
# Hot Sale Business Men Quart Watches Luxury Waterproof S...
# ['Hot']
# ...

# %%
# soup.find("div", class_="Nx9bqj").text
price=[]
for i in soup("div",class_="hZ3P6w"):
    print(i.text)
    price.append(i.text)
# Out:
# ₹187
# ₹166
# ₹399
# ₹1,799
# ₹198
# ₹240
# ₹599
# ₹548
# ₹375
# ₹404
# ₹393
# ₹228
# ₹349
# ₹550
# ₹579
# ₹170
# ₹269
# ₹263
# ₹379
# ₹579
# ₹2,399
# ₹260
# ₹279
# ₹345
# ₹344
# ₹548
# ₹237
# ₹166
# ₹3,995
# ₹379
# ₹113
# ₹192
# ₹549
# ₹349
# ₹400
# ₹374
# ₹2,279
# ₹312
# ₹3,889
# ₹550
# ₹344
# ₹3,995
# ₹549
# ₹3,889
# ₹228

# %%
# soup.find("div", class_="XQDdHH").text
discount=[]
for i in soup.find_all("div",class_="HQe8jr"):
    print(i.text)
    discount.append(i.text)
# Out:
# 81% off
# 83% off
# 88% off
# 55% off
# 80% off
# 81% off
# 64% off
# 8% off
# 87% off
# 82% off
# 89% off
# 89% off
# 73% off
# 8% off
# 61% off
# 82% off
# 87% off
# 86% off
# 76% off
# 55% off
# 48% off
# 86% off
# 85% off
# 88% off
# 77% off
# 8% off
# 88% off
# 83% off
# 70% off
# 71% off
# 61% off
# 64% off
# 85% off
# 86% off
# 84% off
# 73% off
# 84% off
# 80% off
# 8% off
# 77% off
# 64% off
# 80% off
# 89% off

# %%
# soup.find("div", class_="XQDdHH").text
availability=[]
for i in soup.find_all("div",class_="HZ0E6r Rm9_cy"):
    print(i.text)
    availability.append(i.text)
# Out:
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Only few left
# Bank Offer
# Only 3 left
# Only few left
# Only few left
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Only few left
# Top Discount of the Sale
# Only few left
# Top Discount of the Sale
# Top Discount of the Sale
# Only few left
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Only 1 left
# Only few left
# Only few left
# Only few left
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Only few left

# %%
name=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    name.append(i.text)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# Men's and Women's Watch Box Holder Organizer Case in Bl...
# Luxury Serpent-Inspired Coil Watch with Crystal Encrust...
# Velvet box Watch Box
# PREMBROTHERS Heavy Metal Chain with Secure Lock Technol...
# Crysendo Nylon Strap Compatible with AppleWatch Series ...
# Hot Sale Business Men Quart Watches Luxury Waterproof S...
# Digital Watch  - For Boys & Girls 8517
# Men's and Women's Watch Box Holder Organizer Case in Bl...
# T10 Ultra2 smartwatch with calling Hybrid Smartwatch Wa...
# Man Analog Watch  - For Men LD-BK0054-OCEAN Silicone St...
# Silver Dial Analog Watch  - For Women TWTL10104
# Hot Sale Business Men Quart Watches Luxury Waterproof S...
# Round 33mm Silver Dial Analog Watch  - For Men TW0TG730...
# Silicone Strap Boys Analog Watch  - For Men SL-01
# Minimalist Series | Smart Watch Strap | Smart Clip | So...
# ...

# %%
len(brand)
# Out:
# 40

# %%
price = price[:40]
discount=discount[:40]
name=name[:40]
availability=availability[:40]

# %%
# phones={"Brand":brand,"Color":color,"Storage":storage,"Rating":rating,"Screen_size":sreen_size,"Battery":battery,"Price":price}

b6= {"Brand": brand, "Price":price,"Discount":discount,"Availability":availability,"Name":name}

# %%
b6
# Out:
# {'Brand': ['Analog',
#   'Analog',
#   'Men',
#   'Luxury',
#   'Velvet',
#   'PREMBROTHERS',
#   'Crysendo',
#   'Hot',
#   'Digital',
#   'Men',
#   'T',
#   'Man',
#   'Silver',
#   'Hot',
#   'Round',
#   'Silicone',
#   'Minimalist',
#   'Elegant',
#   'Premium',
#   'Pink',
#   'Multifunction',
#   'Day',
#   'Professional',
#   'Car',
#   'TSHOT',
#   'Hot',
#   'Minimalist',
#   'Analog',
#   'Youth',
#   'Silver',
#   'Neupac',
#   'Digital',
#   'Black',
#   'Analog',
#   'T',
#   'Men',
#   'Gold',
#   'Vintage',
#   'Gold',
#   'Hot'],
#  'Price': ['₹187',
#   '₹166',
#   '₹399',
#   '₹1,799',
#   '₹198',
#   '₹240',
#   '₹599',
#   '₹548',
#   '₹375',
#   '₹404',
#   '₹393',
#   '₹228',
#   '₹349',
#   '₹550',
#   '₹579',
#   '₹170',
#   '₹269',
#   '₹263',
#   '₹379',
#   '₹579',
#   '₹2,399',
#   '₹260',
#   '₹279',
#   '₹345',
#   '₹344',
#   '₹548',
#   '₹237',
#   '₹166',
#   '₹3,995',
#   '₹379',
#   '₹113',
#   '₹192',
#   '₹549',
#   '₹349',
#   '₹400',
# ...

# %%
import pandas as pd
b6 = pd.DataFrame(b6)

# %%
b6
# Out:
#             Brand   Price Discount              Availability  \
# 0          Analog    ₹187  81% off  Top Discount of the Sale
# 1          Analog    ₹166  83% off  Top Discount of the Sale
# 2             Men    ₹399  88% off  Top Discount of the Sale
# 3          Luxury  ₹1,799  55% off             Only few left
# 4          Velvet    ₹198  80% off             Only few left
# 5    PREMBROTHERS    ₹240  81% off                Bank Offer
# 6        Crysendo    ₹599  64% off               Only 3 left
# 7             Hot    ₹548   8% off             Only few left
# 8         Digital    ₹375  87% off             Only few left
# 9             Men    ₹404  82% off  Top Discount of the Sale
# 10              T    ₹393  89% off  Top Discount of the Sale
# 11            Man    ₹228  89% off  Top Discount of the Sale
# 12         Silver    ₹349  73% off  Top Discount of the Sale
# 13            Hot    ₹550   8% off             Only few left
# ...

# %%
url7="https://www.flipkart.com/search?q=watches&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&sort=relevance&page=7"

# %%
url = url7
page = requests.get(url,headers = headers)
soup = BeautifulSoup(page.text)

# %%
page
# Out:
# <Response [200]>

# %%
import re
import numpy as np

# %%
soup.find_all("a", class_="atJtCj")
# Out:
# [<a class="atJtCj" href="/shivark-analog-watch-boys/p/itm2ab544b831fd1?pid=WATHBDS5RCZPXSDK&amp;lid=LSTWATHBDS5RCZPXSDK7BJK2T&amp;marketplace=FLIPKART&amp;q=watches&amp;store=r18&amp;srno=s_7_241&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_QEPW24mYaDlmgBjbmNmU19cBZTQOVV7fDnnWXvi_OfxoyP0ZHy0VLvLvnqAWwpmVrSrC5iHEVgUT8tylfs2KbA%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=a7zcory6dc0000001769060955594&amp;qH=2d6b6aad43dffa91" rel="noopener noreferrer" target="_blank" title="Analog Watch  - For Boys New Attractive Designer Blue Dial Watch and King Bracelet Combo">Analog Watch  - For Boys New Attractive Designer Blue D...</a>,
# ...

# %%
brand=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    regex=re.findall("^[a-zA-Z]+",i.text)
    print(regex)
    if regex:
        brand.append(regex[0])
    else:
        brand.append(np.nan)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# ['Analog']
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# ['Analog']
# TooHype 22mm Soft Pack Of 3 (compatible Watch List In P...
# ['TooHype']
# Special Summer Collection Water Resistant Upto 5ATM Ana...
# ['Special']
# Analog Watch  - For Boys & Girls Man watch urdu pack .1
# ['Analog']
# Analog Watch  - For Women AMWW307
# ['Analog']
# T10 Ultra2 smartwatch with calling Hybrid Smartwatch Wa...
# ['T']
# Minimalist Series | Smart Watch Strap | Smart Clip | So...
# ['Minimalist']
# Round 26mm Purple Dial Analog Watch  - For Women TWEL11...
# ['Round']
# Analog Watch  - For Men NR1648YM02,NP1648YM02
# ['Analog']
# Man Analog Watch  - For Men LD-BK0054-OCEAN Silicone St...
# ['Man']
# Elegant Series Square Quartz For /Boys Wrist Analog Wat...
# ['Elegant']
# Titan Raga Showstopper RoseGold Dial RoseGold MetalStra...
# ['Titan']
# NEW DESIGNER SQUARE DIAL QUARTZ Analog Watch  - For Men...
# ['NEW']
# ...

# %%
# soup.find("div", class_="Nx9bqj").text
price=[]
for i in soup("div",class_="hZ3P6w"):
    print(i.text)
    price.append(i.text)
# Out:
# ₹187
# ₹162
# ₹222
# ₹499
# ₹225
# ₹639
# ₹393
# ₹269
# ₹1,189
# ₹1,994
# ₹228
# ₹263
# ₹6,394
# ₹255
# ₹178
# ₹226
# ₹2,399
# ₹260
# ₹260
# ₹465
# ₹237
# ₹166
# ₹183
# ₹448
# ₹297
# ₹207
# ₹113
# ₹192
# ₹705
# ₹354
# ₹448
# ₹2,279
# ₹220
# ₹230
# ₹781
# ₹285
# ₹289
# ₹299
# ₹239
# ₹2,848
# ₹299
# ₹228
# ₹222
# ₹113
# ₹354

# %%
# soup.find("div", class_="XQDdHH").text
discount=[]
for i in soup.find_all("div",class_="HQe8jr"):
    print(i.text)
    discount.append(i.text)
# Out:
# 81% off
# 83% off
# 72% off
# 83% off
# 43% off
# 80% off
# 89% off
# 87% off
# 48% off
# 89% off
# 86% off
# 84% off
# 86% off
# 72% off
# 48% off
# 86% off
# 62% off
# 84% off
# 88% off
# 83% off
# 89% off
# 70% off
# 77% off
# 79% off
# 71% off
# 61% off
# 52% off
# 85% off
# 77% off
# 73% off
# 85% off
# 67% off
# 76% off
# 71% off
# 88% off
# 88% off
# 76% off
# 10% off
# 88% off
# 89% off
# 72% off
# 71% off
# 85% off

# %%
# soup.find("div", class_="XQDdHH").text
availability=[]
for i in soup.find_all("div",class_="HZ0E6r Rm9_cy"):
    print(i.text)
    availability.append(i.text)
# Out:
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer

# %%
name=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    name.append(i.text)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# TooHype 22mm Soft Pack Of 3 (compatible Watch List In P...
# Special Summer Collection Water Resistant Upto 5ATM Ana...
# Analog Watch  - For Boys & Girls Man watch urdu pack .1
# Analog Watch  - For Women AMWW307
# T10 Ultra2 smartwatch with calling Hybrid Smartwatch Wa...
# Minimalist Series | Smart Watch Strap | Smart Clip | So...
# Round 26mm Purple Dial Analog Watch  - For Women TWEL11...
# Analog Watch  - For Men NR1648YM02,NP1648YM02
# Man Analog Watch  - For Men LD-BK0054-OCEAN Silicone St...
# Elegant Series Square Quartz For /Boys Wrist Analog Wat...
# Titan Raga Showstopper RoseGold Dial RoseGold MetalStra...
# NEW DESIGNER SQUARE DIAL QUARTZ Analog Watch  - For Men...
# Analog Watch  - For Men Square Dial Silicone Strap
# Techpugg Waterproof Digital LCD Stopwatch Chronograph T...
# Multifunction Black Dial Analog Watch  - For Men TW000T...
# ...

# %%
len(brand)
# Out:
# 40

# %%
price = price[:40]
discount=discount[:40]
name=name[:40]
availability=availability[:40]

# %%
# phones={"Brand":brand,"Color":color,"Storage":storage,"Rating":rating,"Screen_size":sreen_size,"Battery":battery,"Price":price}

b7= {"Brand": brand, "Price":price,"Discount":discount,"Availability":availability,"Name":name}

# %%
b7
# Out:
# {'Brand': ['Analog',
#   'Analog',
#   'TooHype',
#   'Special',
#   'Analog',
#   'Analog',
#   'T',
#   'Minimalist',
#   'Round',
#   'Analog',
#   'Man',
#   'Elegant',
#   'Titan',
#   'NEW',
#   'Analog',
#   'Techpugg',
#   'Multifunction',
#   'Day',
#   'Jouet',
#   'Royal',
#   'Minimalist',
#   'Analog',
#   'Analog',
#   'Transparent',
#   'Wodec',
#   'TRENDINGVIEW',
#   'Neupac',
#   'Digital',
#   'Luxuro',
#   'Date',
#   'Apex',
#   'Gold',
#   'EVR',
#   'SWADESI',
#   'Analog',
#   'UNISEX',
#   'Nautilus',
#   'Original',
#   'Analog',
#   'Titan'],
#  'Price': ['₹187',
#   '₹162',
#   '₹222',
#   '₹499',
#   '₹225',
#   '₹639',
#   '₹393',
#   '₹269',
#   '₹1,189',
#   '₹1,994',
#   '₹228',
#   '₹263',
#   '₹6,394',
#   '₹255',
#   '₹178',
#   '₹226',
#   '₹2,399',
#   '₹260',
#   '₹260',
#   '₹465',
#   '₹237',
#   '₹166',
#   '₹183',
#   '₹448',
#   '₹297',
#   '₹207',
#   '₹113',
#   '₹192',
#   '₹705',
#   '₹354',
#   '₹448',
#   '₹2,279',
#   '₹220',
# ...

# %%
import pandas as pd
b7 = pd.DataFrame(b7)

# %%
b7
# Out:
#             Brand   Price Discount              Availability  \
# 0          Analog    ₹187  81% off  Top Discount of the Sale
# 1          Analog    ₹162  83% off  Top Discount of the Sale
# 2         TooHype    ₹222  72% off                Bank Offer
# 3         Special    ₹499  83% off                Bank Offer
# 4          Analog    ₹225  43% off                Bank Offer
# 5          Analog    ₹639  80% off  Top Discount of the Sale
# 6               T    ₹393  89% off  Top Discount of the Sale
# 7      Minimalist    ₹269  87% off  Top Discount of the Sale
# 8           Round  ₹1,189  48% off  Top Discount of the Sale
# 9          Analog  ₹1,994  89% off                Bank Offer
# 10            Man    ₹228  86% off  Top Discount of the Sale
# 11        Elegant    ₹263  84% off  Top Discount of the Sale
# 12          Titan  ₹6,394  86% off                Bank Offer
# 13            NEW    ₹255  72% off                Bank Offer
# ...

# %%
url8="https://www.flipkart.com/search?q=watches&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&sort=relevance&page=8"

# %%
url = url8
page = requests.get(url,headers = headers)
soup = BeautifulSoup(page.text)

# %%
page
# Out:
# <Response [200]>

# %%
import re
import numpy as np

# %%
soup.find_all("a", class_="atJtCj")
# Out:
# [<a class="atJtCj" href="/shivark-analog-watch-boys/p/itm2ab544b831fd1?pid=WATHBDS5RCZPXSDK&amp;lid=LSTWATHBDS5RCZPXSDK7BJK2T&amp;marketplace=FLIPKART&amp;q=watches&amp;store=r18&amp;srno=s_8_281&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_t-Imhz51-I6m8GtLz4DcEPI8BdvQo0eaZUaUdJIyNQjjTtyQ08zHltqQMP31wGU2rSrC5iHEVgUT8tylfs2KbA%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=85yzbmck9c0000001769061145699&amp;qH=2d6b6aad43dffa91" rel="noopener noreferrer" target="_blank" title="Analog Watch  - For Boys New Attractive Designer Blue Dial Watch and King Bracelet Combo">Analog Watch  - For Boys New Attractive Designer Blue D...</a>,
# ...

# %%
brand=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    regex=re.findall("^[a-zA-Z]+",i.text)
    print(regex)
    if regex:
        brand.append(regex[0])
    else:
        brand.append(np.nan)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# ['Analog']
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# ['Analog']
# Titan Regalia White & Grey Dial Brown LeatherStrap Anal...
# ['Titan']
# Titan Workwear Multifunction Black Dial Brown LeatherSt...
# ['Titan']
# Titan Neo Splash Sartorial Multifunction Blue Dial Blue...
# ['Titan']
# Rishox Antique Style One Piece Quartz Pocket Watch Key ...
# ['Rishox']
# PREMBROTHERS Heavy Metal Chain with Secure Lock Technol...
# ['PREMBROTHERS']
# T10 Ultra2 smartwatch with calling Hybrid Smartwatch Wa...
# ['T']
# Round Rose Gold Analog Watch  - For Women DB Brown DJ W...
# ['Round']
# Analog Watch  - For Men Red flower wheels
# ['Analog']
# Minimalist Series | Smart Watch Strap | Smart Clip | So...
# ['Minimalist']
# Man Analog Watch  - For Men LD-BK0054-OCEAN Silicone St...
# ['Man']
# TONSY SR626SW, LR626, 364A, AG4, 377, 377a - 1.5V Alkal...
# ['TONSY']
# 10 compartment Watch Box Holder Organizer Case for Men ...
# ...

# %%
# soup.find("div", class_="Nx9bqj").text
price=[]
for i in soup("div",class_="hZ3P6w"):
    print(i.text)
    price.append(i.text)
# Out:
# ₹187
# ₹162
# ₹6,795
# ₹5,320
# ₹6,795
# ₹271
# ₹240
# ₹393
# ₹222
# ₹351
# ₹269
# ₹228
# ₹205
# ₹451
# ₹4,483
# ₹567
# ₹2,399
# ₹263
# ₹173
# ₹1,394
# ₹260
# ₹237
# ₹376
# ₹499
# ₹259
# ₹270
# ₹166
# ₹113
# ₹628
# ₹214
# ₹192
# ₹2,279
# ₹4,351
# ₹259
# ₹157
# ₹279
# ₹448
# ₹289
# ₹498
# ₹218
# ₹259
# ₹173
# ₹228
# ₹113
# ₹157

# %%
# soup.find("div", class_="XQDdHH").text
discount=[]
for i in soup.find_all("div",class_="HQe8jr"):
    print(i.text)
    discount.append(i.text)
# Out:
# 81% off
# 83% off
# 20% off
# 3% off
# 20% off
# 81% off
# 81% off
# 89% off
# 82% off
# 82% off
# 87% off
# 89% off
# 79% off
# 77% off
# 20% off
# 85% off
# 48% off
# 86% off
# 88% off
# 86% off
# 88% off
# 62% off
# 75% off
# 80% off
# 84% off
# 83% off
# 71% off
# 84% off
# 46% off
# 61% off
# 73% off
# 15% off
# 87% off
# 89% off
# 53% off
# 77% off
# 88% off
# 75% off
# 75% off
# 80% off
# 88% off
# 89% off
# 71% off
# 89% off

# %%
# soup.find("div", class_="XQDdHH").text
availability=[]
for i in soup.find_all("div",class_="HZ0E6r Rm9_cy"):
    print(i.text)
    availability.append(i.text)
# Out:
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale

# %%
name=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    name.append(i.text)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# Titan Regalia White & Grey Dial Brown LeatherStrap Anal...
# Titan Workwear Multifunction Black Dial Brown LeatherSt...
# Titan Neo Splash Sartorial Multifunction Blue Dial Blue...
# Rishox Antique Style One Piece Quartz Pocket Watch Key ...
# PREMBROTHERS Heavy Metal Chain with Secure Lock Technol...
# T10 Ultra2 smartwatch with calling Hybrid Smartwatch Wa...
# Round Rose Gold Analog Watch  - For Women DB Brown DJ W...
# Analog Watch  - For Men Red flower wheels
# Minimalist Series | Smart Watch Strap | Smart Clip | So...
# Man Analog Watch  - For Men LD-BK0054-OCEAN Silicone St...
# TONSY SR626SW, LR626, 364A, AG4, 377, 377a - 1.5V Alkal...
# 10 compartment Watch Box Holder Organizer Case for Men ...
# Titan On Trend Multifunction Silver Dial Brown LeatherS...
# Watch Box For Men & Women, Watch Case, Watch Storage Bo...
# ...

# %%
len(brand)
# Out:
# 40

# %%
price = price[:40]
discount=discount[:40]
name=name[:40]
availability=availability[:40]

# %%
# phones={"Brand":brand,"Color":color,"Storage":storage,"Rating":rating,"Screen_size":sreen_size,"Battery":battery,"Price":price}

b8= {"Brand": brand, "Price":price,"Discount":discount,"Availability":availability,"Name":name}

# %%
b8
# Out:
# {'Brand': ['Analog',
#   'Analog',
#   'Titan',
#   'Titan',
#   'Titan',
#   'Rishox',
#   'PREMBROTHERS',
#   'T',
#   'Round',
#   'Analog',
#   'Minimalist',
#   'Man',
#   'TONSY',
#   nan,
#   'Titan',
#   'Watch',
#   'Multifunction',
#   'Elegant',
#   'Multi',
#   'Fastrack',
#   'Day',
#   'Minimalist',
#   'Trending',
#   'Big',
#   'Brown',
#   'Elegant',
#   'Analog',
#   'Neupac',
#   'Watch',
#   'Roycee',
#   'Digital',
#   'Gold',
#   'Titan',
#   'QUXXA',
#   'Priavy',
#   'Party',
#   'Apex',
#   'Nautilus',
#   'T',
#   'Elegant'],
#  'Price': ['₹187',
#   '₹162',
#   '₹6,795',
#   '₹5,320',
#   '₹6,795',
#   '₹271',
#   '₹240',
#   '₹393',
#   '₹222',
#   '₹351',
#   '₹269',
#   '₹228',
#   '₹205',
#   '₹451',
#   '₹4,483',
#   '₹567',
#   '₹2,399',
#   '₹263',
#   '₹173',
#   '₹1,394',
#   '₹260',
#   '₹237',
#   '₹376',
#   '₹499',
#   '₹259',
#   '₹270',
#   '₹166',
#   '₹113',
#   '₹628',
#   '₹214',
#   '₹192',
#   '₹2,279',
#   '₹4,351',
#   '₹259',
# ...

# %%
import pandas as pd
b8 = pd.DataFrame(b8)

# %%
b8
# Out:
#             Brand   Price Discount              Availability  \
# 0          Analog    ₹187  81% off  Top Discount of the Sale
# 1          Analog    ₹162  83% off  Top Discount of the Sale
# 2           Titan  ₹6,795  20% off                Bank Offer
# 3           Titan  ₹5,320   3% off                Bank Offer
# 4           Titan  ₹6,795  20% off                Bank Offer
# 5          Rishox    ₹271  81% off                Bank Offer
# 6    PREMBROTHERS    ₹240  81% off                Bank Offer
# 7               T    ₹393  89% off  Top Discount of the Sale
# 8           Round    ₹222  82% off                Bank Offer
# 9          Analog    ₹351  82% off                Bank Offer
# 10     Minimalist    ₹269  87% off  Top Discount of the Sale
# 11            Man    ₹228  89% off  Top Discount of the Sale
# 12          TONSY    ₹205  79% off  Top Discount of the Sale
# 13            NaN    ₹451  77% off                Bank Offer
# ...

# %%
url9="https://www.flipkart.com/search?q=watches&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&sort=relevance&page=19"

# %%
url = url9
page = requests.get(url,headers = headers)
soup = BeautifulSoup(page.text)

# %%
page
# Out:
# <Response [200]>

# %%
import re
import numpy as np

# %%
soup.find_all("a", class_="atJtCj")
# Out:
# [<a class="atJtCj" href="/shivark-analog-watch-boys/p/itm2ab544b831fd1?pid=WATHBDS5RCZPXSDK&amp;lid=LSTWATHBDS5RCZPXSDK7BJK2T&amp;marketplace=FLIPKART&amp;q=watches&amp;store=r18&amp;srno=s_19_721&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_N5uDDyaa12NwV-QgHw2lURJdg2WeL7sGuWKqg70FsDsyhMxSrSXrGjTAuVpuarwUrSrC5iHEVgUT8tylfs2KbA%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=euqapar1cg0000001769061445482&amp;qH=2d6b6aad43dffa91" rel="noopener noreferrer" target="_blank" title="Analog Watch  - For Boys New Attractive Designer Blue Dial Watch and King Bracelet Combo">Analog Watch  - For Boys New Attractive Designer Blue D...</a>,
# ...

# %%
brand=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    regex=re.findall("^[a-zA-Z]+",i.text)
    print(regex)
    if regex:
        brand.append(regex[0])
    else:
        brand.append(np.nan)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# ['Analog']
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# ['Analog']
# Digital Watch  - For Men Roc-144
# ['Digital']
# Titan Neo Splash Multifunction Black Dial Black Leather...
# ['Titan']
# Titan On Trend Multifunction White Dial Brown LeatherSt...
# ['Titan']
# Titan Purple Stackables Pink Dial Rose Gold Stainless S...
# ['Titan']
# PREMBROTHERS Heavy Metal Chain with Secure Lock Technol...
# ['PREMBROTHERS']
# Branded Bracelet | Gold Plated | Studded | 3D Cut Glass...
# ['Branded']
# Analog Watch  - For Men AVM0029
# ['Analog']
# Raga Showstopper 3.0 Analog Watch  - For Women 95352WM0...
# ['Raga']
# T10 Ultra2 smartwatch with calling Hybrid Smartwatch Wa...
# ['T']
# Watch Box Organizer 6 Slots Organizer Case for Men and ...
# ['Watch']
# Titan Raga Love All Brown Dial Brown MetalStrap Analog ...
# ['Titan']
# Titan Karishma with Day & Date Blue Dial Silver Stainle...
# ['Titan']
# ...

# %%
# soup.find("div", class_="Nx9bqj").text
price=[]
for i in soup("div",class_="hZ3P6w"):
    print(i.text)
    price.append(i.text)
# Out:
# ₹187
# ₹162
# ₹182
# ₹5,436
# ₹9,880
# ₹6,115
# ₹240
# ₹322
# ₹230
# ₹5,394
# ₹393
# ₹451
# ₹9,588
# ₹2,475
# ₹297
# ₹186
# ₹250
# ₹247
# ₹290
# ₹193
# ₹269
# ₹228
# ₹267
# ₹244
# ₹338
# ₹251
# ₹299
# ₹113
# ₹5,054
# ₹360
# ₹2,279
# ₹260
# ₹160
# ₹196
# ₹222
# ₹408
# ₹448
# ₹25,128
# ₹242
# ₹787
# ₹247
# ₹297
# ₹230
# ₹9,588
# ₹451

# %%
# soup.find("div", class_="XQDdHH").text
discount=[]
for i in soup.find_all("div",class_="HQe8jr"):
    print(i.text)
    discount.append(i.text)
# Out:
# 81% off
# 83% off
# 81% off
# 6% off
# 25% off
# 20% off
# 81% off
# 89% off
# 74% off
# 89% off
# 69% off
# 25% off
# 20% off
# 50% off
# 76% off
# 49% off
# 84% off
# 81% off
# 78% off
# 87% off
# 89% off
# 73% off
# 75% off
# 66% off
# 87% off
# 80% off
# 71% off
# 9% off
# 81% off
# 73% off
# 86% off
# 83% off
# 80% off
# 77% off
# 79% off
# 77% off
# 38% off
# 75% off
# 47% off
# 84% off
# 50% off
# 74% off
# 25% off
# 69% off

# %%
# soup.find("div", class_="XQDdHH").text
availability=[]
for i in soup.find_all("div",class_="HZ0E6r Rm9_cy"):
    print(i.text)
    availability.append(i.text)
# Out:
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer
# Bank Offer
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer

# %%
name=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    name.append(i.text)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# Digital Watch  - For Men Roc-144
# Titan Neo Splash Multifunction Black Dial Black Leather...
# Titan On Trend Multifunction White Dial Brown LeatherSt...
# Titan Purple Stackables Pink Dial Rose Gold Stainless S...
# PREMBROTHERS Heavy Metal Chain with Secure Lock Technol...
# Branded Bracelet | Gold Plated | Studded | 3D Cut Glass...
# Analog Watch  - For Men AVM0029
# Raga Showstopper 3.0 Analog Watch  - For Women 95352WM0...
# T10 Ultra2 smartwatch with calling Hybrid Smartwatch Wa...
# Watch Box Organizer 6 Slots Organizer Case for Men and ...
# Titan Raga Love All Brown Dial Brown MetalStrap Analog ...
# Titan Karishma with Day & Date Blue Dial Silver Stainle...
# Rayyn [TORO] Thick Strap Design 22 mm Genuine Leather W...
# TooHype 22mm Soft Pack Of 3 (compatible Watch List In P...
# TRENDINGVIEW Premium 20mm Combo Watch Strap with Durabl...
# ...

# %%
len(brand)
# Out:
# 40

# %%
price = price[:40]
discount=discount[:40]
name=name[:40]
availability=availability[:40]

# %%
# phones={"Brand":brand,"Color":color,"Storage":storage,"Rating":rating,"Screen_size":sreen_size,"Battery":battery,"Price":price}

b9= {"Brand": brand, "Price":price,"Discount":discount,"Availability":availability,"Name":name}

# %%
b9
# Out:
# {'Brand': ['Analog',
#   'Analog',
#   'Digital',
#   'Titan',
#   'Titan',
#   'Titan',
#   'PREMBROTHERS',
#   'Branded',
#   'Analog',
#   'Raga',
#   'T',
#   'Watch',
#   'Titan',
#   'Titan',
#   'Rayyn',
#   'TooHype',
#   'TRENDINGVIEW',
#   'DAY',
#   'Day',
#   'Firetook',
#   'Minimalist',
#   'Man',
#   'EDY',
#   'ACM',
#   'Analog',
#   'Analog',
#   'Minimalist',
#   'Neupac',
#   'Titan',
#   'UL',
#   'Gold',
#   'Day',
#   'Fancy',
#   'silver',
#   'TRENDINGVIEW',
#   'ARSH',
#   'Apex',
#   'Analog',
#   'Rayyn',
#   'W'],
#  'Price': ['₹187',
#   '₹162',
#   '₹182',
#   '₹5,436',
#   '₹9,880',
#   '₹6,115',
#   '₹240',
#   '₹322',
#   '₹230',
#   '₹5,394',
#   '₹393',
#   '₹451',
#   '₹9,588',
#   '₹2,475',
#   '₹297',
#   '₹186',
#   '₹250',
#   '₹247',
#   '₹290',
#   '₹193',
#   '₹269',
#   '₹228',
#   '₹267',
#   '₹244',
#   '₹338',
#   '₹251',
#   '₹299',
#   '₹113',
#   '₹5,054',
#   '₹360',
#   '₹2,279',
#   '₹260',
#   '₹160',
#   '₹196',
#   '₹222',
# ...

# %%
import pandas as pd
b9 = pd.DataFrame(b9)

# %%
b9
# Out:
#            Brand    Price Discount              Availability  \
# 0         Analog     ₹187  81% off  Top Discount of the Sale
# 1         Analog     ₹162  83% off  Top Discount of the Sale
# 2        Digital     ₹182  81% off  Top Discount of the Sale
# 3          Titan   ₹5,436   6% off                Bank Offer
# 4          Titan   ₹9,880  25% off                Bank Offer
# 5          Titan   ₹6,115  20% off                Bank Offer
# 6   PREMBROTHERS     ₹240  81% off                Bank Offer
# 7        Branded     ₹322  89% off  Top Discount of the Sale
# 8         Analog     ₹230  74% off                Bank Offer
# 9           Raga   ₹5,394  89% off                Bank Offer
# 10             T     ₹393  69% off  Top Discount of the Sale
# 11         Watch     ₹451  25% off                Bank Offer
# 12         Titan   ₹9,588  20% off                Bank Offer
# 13         Titan   ₹2,475  50% off                Bank Offer
# ...

# %%
url10="https://www.flipkart.com/search?q=watches&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&sort=relevance&page=10"

# %%
url = url10
page = requests.get(url,headers = headers)
soup = BeautifulSoup(page.text)

# %%
page
# Out:
# <Response [200]>

# %%
import re
import numpy as np

# %%
soup.find_all("a", class_="atJtCj")
# Out:
# [<a class="atJtCj" href="/shivark-analog-watch-boys/p/itm2ab544b831fd1?pid=WATHBDS5RCZPXSDK&amp;lid=LSTWATHBDS5RCZPXSDK7BJK2T&amp;marketplace=FLIPKART&amp;q=watches&amp;store=r18&amp;srno=s_10_361&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_gpTvnTh0CZ5J6PSo2SmVupC0a18gDgkUYCw_6awafH0CBhBjPbTa7_442Q5SY0PjrSrC5iHEVgUT8tylfs2KbA%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=7l88tgwgj40000001769061647541&amp;qH=2d6b6aad43dffa91" rel="noopener noreferrer" target="_blank" title="Analog Watch  - For Boys New Attractive Designer Blue Dial Watch and King Bracelet Combo">Analog Watch  - For Boys New Attractive Designer Blue D...</a>,
# ...

# %%
brand=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    regex=re.findall("^[a-zA-Z]+",i.text)
    print(regex)
    if regex:
        brand.append(regex[0])
    else:
        brand.append(np.nan)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# ['Analog']
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# ['Analog']
# Titan Mechanical Slimline Automatic Green Dial Gold SS ...
# ['Titan']
# Rayyn OLMO UNIVERSAL 20 mm Resin Watch Strap
# ['Rayyn']
# ClaasyMen Premium Skeleton Series Analog Watch for Men ...
# ['ClaasyMen']
# New Black and Tan Watchcase Watch Box
# ['New']
# Branded Bracelet | Gold Plated | Studded | 3D Cut Glass...
# ['Branded']
# Gold Analog Watch  - For Women DK11467-3
# ['Gold']
# Titan Workwear Multifunction Black Dial Brown LeatherSt...
# ['Titan']
# Fastrack With Date Black Dial Brown LeatherStrap Analog...
# ['Fastrack']
# Minimalist Series | Smart Watch Strap | Smart Clip | So...
# ['Minimalist']
# Man Analog Watch  - For Men LD-BK0054-OCEAN Silicone St...
# ['Man']
# Titan Slim Multifunction Black Dial Black Stainless Ste...
# ['Titan']
# Titan Karishma With Day & Date Black Dial Black Stainle...
# ['Titan']
# ...

# %%
# soup.find("div", class_="Nx9bqj").text
price=[]
for i in soup("div",class_="hZ3P6w"):
    print(i.text)
    price.append(i.text)
# Out:
# ₹187
# ₹162
# ₹18,746
# ₹361
# ₹401
# ₹439
# ₹322
# ₹2,279
# ₹5,372
# ₹1,899
# ₹269
# ₹228
# ₹5,035
# ₹3,835
# ₹2,875
# ₹164
# ₹264
# ₹260
# ₹478
# ₹297
# ₹237
# ₹166
# ₹316
# ₹179
# ₹1,974
# ₹269
# ₹192
# ₹250
# ₹305
# ₹332
# ₹299
# ₹185
# ₹293
# ₹6,795
# ₹167
# ₹565
# ₹8,489
# ₹176
# ₹403
# ₹410
# ₹1,974
# ₹332
# ₹167
# ₹3,835
# ₹299

# %%
# soup.find("div", class_="XQDdHH").text
discount=[]
for i in soup.find_all("div",class_="HQe8jr"):
    print(i.text)
    discount.append(i.text)
# Out:
# 81% off
# 83% off
# 25% off
# 63% off
# 86% off
# 79% off
# 89% off
# 73% off
# 15% off
# 23% off
# 87% off
# 89% off
# 20% off
# 20% off
# 20% off
# 72% off
# 86% off
# 86% off
# 81% off
# 85% off
# 88% off
# 83% off
# 68% off
# 82% off
# 85% off
# 61% off
# 84% off
# 83% off
# 72% off
# 88% off
# 81% off
# 63% off
# 20% off
# 87% off
# 59% off
# 59% off
# 82% off
# 80% off
# 58% off
# 72% off
# 87% off
# 20% off
# 88% off

# %%
# soup.find("div", class_="XQDdHH").text
availability=[]
for i in soup.find_all("div",class_="HZ0E6r Rm9_cy"):
    print(i.text)
    availability.append(i.text)
# Out:
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale
# Top Discount of the Sale
# Bank Offer
# Bank Offer
# Bank Offer
# Bank Offer
# Top Discount of the Sale
# Bank Offer
# Top Discount of the Sale

# %%
name=[]
for i in soup.find_all("a",class_="atJtCj"):
    print(i.text)
    name.append(i.text)
# Out:
# Analog Watch  - For Boys New Attractive Designer Blue D...
# Analog Watch  - For Men PZ-2001 Trendy Silicone Strap
# Titan Mechanical Slimline Automatic Green Dial Gold SS ...
# Rayyn OLMO UNIVERSAL 20 mm Resin Watch Strap
# ClaasyMen Premium Skeleton Series Analog Watch for Men ...
# New Black and Tan Watchcase Watch Box
# Branded Bracelet | Gold Plated | Studded | 3D Cut Glass...
# Gold Analog Watch  - For Women DK11467-3
# Titan Workwear Multifunction Black Dial Brown LeatherSt...
# Fastrack With Date Black Dial Brown LeatherStrap Analog...
# Minimalist Series | Smart Watch Strap | Smart Clip | So...
# Man Analog Watch  - For Men LD-BK0054-OCEAN Silicone St...
# Titan Slim Multifunction Black Dial Black Stainless Ste...
# Titan Karishma With Day & Date Black Dial Black Stainle...
# Titan Workwear Green Dial Green Leather Strap Analog Wa...
# waterproof kids watches for boys Digital Watch  - For B...
# Day And Date Functioning High Quality Combo Of King Pri...
# ...

# %%
len(brand)
# Out:
# 40

# %%
price = price[:40]
discount=discount[:40]
name=name[:40]
availability=availability[:40]

# %%
# phones={"Brand":brand,"Color":color,"Storage":storage,"Rating":rating,"Screen_size":sreen_size,"Battery":battery,"Price":price}

b10= {"Brand": brand, "Price":price,"Discount":discount,"Availability":availability,"Name":name}

# %%
b10
# Out:
# {'Brand': ['Analog',
#   'Analog',
#   'Titan',
#   'Rayyn',
#   'ClaasyMen',
#   'New',
#   'Branded',
#   'Gold',
#   'Titan',
#   'Fastrack',
#   'Minimalist',
#   'Man',
#   'Titan',
#   'Titan',
#   'Titan',
#   'waterproof',
#   'Day',
#   'Day',
#   'Watch',
#   'Set',
#   'Minimalist',
#   'Analog',
#   'trendy',
#   'SP',
#   'Titan',
#   'Elegant',
#   'Digital',
#   'DAY',
#   'Trendy',
#   'Premium',
#   'Original',
#   'Analog',
#   'Roycee',
#   'Titan',
#   'Latest',
#   'Rayyn',
#   'Black',
#   'Silicone',
#   'T',
#   'Rayyn'],
#  'Price': ['₹187',
#   '₹162',
#   '₹18,746',
#   '₹361',
#   '₹401',
#   '₹439',
#   '₹322',
#   '₹2,279',
#   '₹5,372',
#   '₹1,899',
#   '₹269',
#   '₹228',
#   '₹5,035',
#   '₹3,835',
#   '₹2,875',
#   '₹164',
#   '₹264',
#   '₹260',
#   '₹478',
#   '₹297',
#   '₹237',
#   '₹166',
#   '₹316',
#   '₹179',
#   '₹1,974',
#   '₹269',
#   '₹192',
#   '₹250',
#   '₹305',
#   '₹332',
#   '₹299',
#   '₹185',
#   '₹293',
#   '₹6,795',
# ...

# %%
import pandas as pd
b10 = pd.DataFrame(b10)

# %%
b10
# Out:
#          Brand    Price Discount              Availability  \
# 0       Analog     ₹187  81% off  Top Discount of the Sale
# 1       Analog     ₹162  83% off  Top Discount of the Sale
# 2        Titan  ₹18,746  25% off                Bank Offer
# 3        Rayyn     ₹361  63% off                Bank Offer
# 4    ClaasyMen     ₹401  86% off  Top Discount of the Sale
# 5          New     ₹439  79% off                Bank Offer
# 6      Branded     ₹322  89% off  Top Discount of the Sale
# 7         Gold   ₹2,279  73% off                Bank Offer
# 8        Titan   ₹5,372  15% off                Bank Offer
# 9     Fastrack   ₹1,899  23% off                Bank Offer
# 10  Minimalist     ₹269  87% off  Top Discount of the Sale
# 11         Man     ₹228  89% off  Top Discount of the Sale
# 12       Titan   ₹5,035  20% off                Bank Offer
# 13       Titan   ₹3,835  20% off                Bank Offer
# 14       Titan   ₹2,875  20% off                Bank Offer
# ...

# %%
df=pd.concat([b1,b2,b3,b4,b5,b6,b7,b8,b9,b10],axis=0,ignore_index=True)
print(df)
# Out:
#         Brand   Price Discount              Availability  \
# 0      Analog    ₹187  81% off  Top Discount of the Sale
# 1    Silicone    ₹170  82% off  Top Discount of the Sale
# 2         Men    ₹399  88% off  Top Discount of the Sale
# 3     Digital    ₹219  78% off             Only few left
# 4     Premium    ₹616  87% off             Only few left
# ..        ...     ...      ...                       ...
# 395     Rayyn    ₹565  59% off                Bank Offer
# 396     Black  ₹8,489  82% off                Bank Offer
# 397  Silicone    ₹176  80% off  Top Discount of the Sale
# 398         T    ₹403  58% off                Bank Offer
# 399     Rayyn    ₹410  72% off  Top Discount of the Sale
#
#                                                   Name
# 0    Analog Watch  - For Boys New Attractive Design...
# 1    Silicone Strap Boys Analog Watch  - For Men SL-01
# 2    Men's and Women's Watch Box Holder Organizer C...
# 3    Digital Watch - For Boys & Girls digital watch...
# ...

# %%
import pandas as pd

# %%
file_path="C:\\Users\\admin\\Desktop\\SSC GD\\webscrap.csv"
df.to_csv(file_path,index=False)
print(f'DataFrame saved to {file_path}')
# Out:
# DataFrame saved to C:\Users\admin\Desktop\SSC GD\webscrap.csv

# %%
1)How many products are listed in the selected category across the first 5 pages?

# %%
len(df)/2
# Out:
# 200.0

# %%
First 5 pages contain 200 products (5 × 40).

# %% [markdown]
# 2)Create a scatter plot for the prices in first page?

# %%
page
# Out:
# <Response [200]>

# %%
df.columns
# Out:
# Index(['Brand', 'Price', 'Discount', 'Availability', 'Name'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# Load your dataset
df = pd.read_csv(r"C:\Users\admin\Desktop\SSC GD\webscrap.csv")

# Clean price column (convert to numbers)
df['price_num'] = df['Price'].str.replace(r'[^0-9]', '', regex=True).astype(int)

# Extract first page (first 40 items)
page1 = df.iloc[:40]

# Scatter plot with improved scaling
plt.figure(figsize=(14,8))            # Larger figure
plt.scatter(page1.index, page1['price_num'], s=120)   # Larger points

plt.xlabel("Product Index", fontsize=14)
plt.ylabel("Price (₹)", fontsize=14)
plt.title("Scatter Plot of Prices - Page 1 (Scaled Up)", fontsize=16)

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
Insight

Your dataset mainly uses:

“Only few left”

“Top Discount of the Sale”

→ No “out of stock” entries were found.

# %%
Q3 — Discount presence (products with vs without discount)

# %%
import pandas as pd
import re

# Load dataset
df = pd.read_csv(r"C:\\Users\\admin\\Desktop\\SSC GD\\webscrap.csv")   # <-- change to your path

# Create clean discount percentage column
df['discount_pct'] = df['Discount'].apply(
    lambda x: int(re.sub(r'[^0-9]', '', str(x))) if pd.notnull(x) else 0
)

# Count products WITH discount
has_discount = df[df['discount_pct'] > 0].shape[0]

# Count products WITHOUT discount
no_discount = df[df['discount_pct'] == 0].shape[0]

print("Products with discount:", has_discount)
print("Products without discount:", no_discount)
# Out:
# Products with discount: 400
# Products without discount: 0

# %%
Insight

All products have a discount percentage, so:

100% products show discounts

# %%
Q6 — Count of products with keywords (title search)

# %%
# Q6 — Count of products with watch-related keywords

keywords = ["watch", "smartwatch", "wrist watch", "digital watch", "analog watch"]

pattern = "|".join(keywords)

watch_count = df['Name'].str.contains(pattern, case=False, na=False).sum()

print("Count of watch-related products:", watch_count)
# Out:
# Count of watch-related products: 298

# %%
Insight

Your data seems to be watches → likely zero matches.

# %%
Q10 — Delivery date comparison (NOT IN DATA)

# %%
if 'delivery_mumbai' in df.columns and 'delivery_delhi' in df.columns:
    df['delivery_diff'] = df['delivery_mumbai'] - df['delivery_delhi']
    print(df['delivery_diff'])
else:
    print("Delivery columns not found in dataset.")
# Out:
# Delivery columns not found in dataset.

# %%
Q18 — Brand dominance in top 20% listings

# %%
top20pct = df.head(int(0.2 * len(df)))
top20pct['Brand'].value_counts()
# Out:
# Brand
# Analog          22
# Digital          4
# Hot              4
# Men              3
# Silicone         2
# EVR              2
# Travel           2
# Silver           2
# Day              2
# Minimalist       2
# VINTAGE          1
# Arabic           1
# The              1
# Branded          1
# REESE            1
# ANALOG           1
# Sabar            1
# Aura             1
# STYLISH          1
# Marlin           1
# Apex             1
# Gold             1
# Man              1
# Original         1
# NEW              1
# T                1
# Rose             1
# Avatar           1
# Car              1
# Premium          1
# Velvet           1
# Vanshika         1
# PREMBROTHERS     1
# Bharasoft        1
# EVERETT          1
# Elegant          1
# Round            1
# Pink             1
# Crysendo         1
# Trending         1
# SP               1
# Jouet            1
# Faux             1
# Professional     1
# Fastrack         1
# Name: count, dtype: int64

# %%
Insight

Expected dominant brands based on your file:

Analog

Silicone

Men

Digital
(These look like poor-quality scraped brand names)

# %%
Q19 —Are value-packed configs (high specs/low price) underrepresented, a gap for new entrants?

# %%
import pandas as pd
import re

# Load your actual dataset
df = pd.read_csv(r"C:\\Users\\admin\\Desktop\\SSC GD\\webscrap.csv")   # <-- CHANGE THIS PATH

# Clean price column
df['price_num'] = df['Price'].apply(lambda x: int(re.sub(r'[^0-9]', '', str(x))))

# Since your dataset has no specs, let's create a placeholder "spec score"
# Example: Use discount percentage as a proxy for “value”
df['discount_pct'] = df['Discount'].apply(lambda x: int(re.sub(r'[^0-9]', '', str(x))))

# Compute value index = high discount + low price
df['value_index'] = df['discount_pct'] / df['price_num']

# Find top 20% value-packed products
threshold = df['value_index'].quantile(0.80)
value_packed = df[df['value_index'] >= threshold]

print("Value-Packed Products (Top 20% by value score):")
print(value_packed[['Brand', 'Name', 'price_num', 'discount_pct', 'value_index']])
# Out:
# Value-Packed Products (Top 20% by value score):
#           Brand                                               Name  price_num  \
# 0        Analog  Analog Watch  - For Boys New Attractive Design...        187
# 1      Silicone  Silicone Strap Boys Analog Watch  - For Men SL-01        170
# 5        Analog  Analog Watch  - For Men PZ-2001 Trendy Silicon...        166
# 6        Velvet                               Velvet box Watch Box        198
# 10       Analog  Analog Watch  - For Men New Stylish Combo Of S...        187
# ..          ...                                                ...        ...
# 380  Minimalist  Minimalist Slim Series | Smart Strap | Smart C...        237
# 381      Analog  Analog Watch  - For Men PZ - Roman Figure Dial...        166
# 383          SP  SP-DZN001 Analog Watch  - For Boys stylish arr...        179
# 386     Digital   Digital Watch  - For Boys G80 Day & Date Display        192
# ...

# %%
Q20 — Do popular / high-rated products have more stock availability across sellers?

# %%
import pandas as pd

# Load your real dataset
df = pd.read_csv(r"C:\\Users\\admin\\Desktop\\SSC GD\\webscrap.csv")   # <-- change to your actual path

# Check if rating and seller columns exist
required_cols = ['rating', 'seller_count', 'Availability']

missing = [c for c in required_cols if c not in df.columns]

if missing:
    print("❌ Cannot compute Q20 because your dataset is missing these columns:")
    print(missing)
else:
    # Clean rating
    df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

    # Clean sellers
    df['seller_count'] = pd.to_numeric(df['seller_count'], errors='coerce')

    # Convert availability text to binary
    df['available'] = df['Availability'].str.contains("in stock|only|available", case=False).astype(int)

    # Correlation
    print("\nCorrelation between rating and seller stock availability:\n")
    print(df[['rating','seller_count']].corr())

    # Comparison
    high = df[df['rating'] >= 4]['seller_count'].mean()
    low = df[df['rating'] < 3.5]['seller_count'].mean()

    print("\nAverage sellers for high-rated products:", high)
    print("Average sellers for low-rated products:", low)
# Out:
# ❌ Cannot compute Q20 because your dataset is missing these columns:
# ['rating', 'seller_count']

# %%
Insight:

High-rated or popular products usually have better stock availability because more sellers prefer listing items that customers trust and buy frequently.

# %%
14. What % of products have ratings <3.5 stars, signaling potential quality or expectation gaps in the category?

# %%
import pandas as pd

# Load dataset (update path)
df = pd.read_csv(r"C:\\Users\\admin\\Desktop\\SSC GD\\webscrap.csv")

# Check if rating column exists
if 'rating' not in df.columns:
    print("❌ The dataset has no 'rating' column. Cannot compute rating statistics.")
else:
    # Convert rating to numeric
    df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

    # Filter products with rating < 3.5
    low_rated = df[df['rating'] < 3.5]

    # Calculate percentage
    percentage = (len(low_rated) / len(df)) * 100

    print(f"Percentage of products with rating < 3.5: {percentage:.2f}%")
# Out:
# ❌ The dataset has no 'rating' column. Cannot compute rating statistics.

# %%
If you add a rating column later, this code will tell you:

What percentage of products fall below 3.5 stars → a signal of quality issues.

# %%
13)What is the implied price elasticity: do higher-spec products command proportionally higher prices per feature?

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# Load your dataset
df = pd.read_csv("C:\\Users\\admin\\Desktop\\SSC GD\\webscrap.csv")

# Clean numeric price 
df['price_num'] = df['Price'].str.replace(r'[^0-9]', '', regex=True).astype(int)

# Clean numeric discount (as proxy for “spec score”)
df['discount_pct'] = df['Discount'].str.replace(r'[^0-9]', '', regex=True).astype(int)

# Avoid log(0)
df = df[(df['discount_pct'] > 0) & (df['price_num'] > 0)]

# Create log variables
df['log_price'] = np.log(df['price_num'])
df['log_spec'] = np.log(df['discount_pct'])

# Run log–log regression → elasticity = coefficient
X = sm.add_constant(df['log_spec'])
model = sm.OLS(df['log_price'], X).fit()

print(model.summary())

# Extract elasticity coefficient
elasticity = model.params['log_spec']
print("\nImplied Price Elasticity of Specs:", elasticity)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              log_price   R-squared:                       0.122
# Model:                            OLS   Adj. R-squared:                  0.120
# Method:                 Least Squares   F-statistic:                     55.39
# Date:                Thu, 22 Jan 2026   Prob (F-statistic):           6.16e-13
# Time:                        14:37:04   Log-Likelihood:                -576.70
# No. Observations:                 400   AIC:                             1157.
# Df Residuals:                     398   BIC:                             1165.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.7001      0.343     25.400      0.000       8.027       9.374
# ...

# %%
Price elasticity helps answer:

“Do brands charge more fairly as specs increase — or are prices inflated?”

# %%
12. Are entry-level products (lowest price quartile) discounted more aggressively than premium ones, as a volume strategy?

# %%
import pandas as pd
import re

# Load dataset
df = pd.read_csv(r"C:\\Users\\admin\\Desktop\\SSC GD\\webscrap.csv")   # <-- change to your correct path

# Clean price
df['price_num'] = df['Price'].apply(lambda x: int(re.sub(r'[^0-9]', '', str(x))))

# Clean discount percentage
df['discount_pct'] = df['Discount'].apply(lambda x: int(re.sub(r'[^0-9]', '', str(x))))

# Compute quartiles
q1 = df['price_num'].quantile(0.25)   # Entry-level
q3 = df['price_num'].quantile(0.75)   # Premium-level

# Entry-level = lowest 25%
entry_level = df[df['price_num'] <= q1]

# Premium = highest 25%
premium = df[df['price_num'] >= q3]

# Average discount comparison
entry_discount = entry_level['discount_pct'].mean()
premium_discount = premium['discount_pct'].mean()

print("Average discount for entry-level (cheapest 25%):", round(entry_discount, 2), "%")
print("Average discount for premium (top 25% price):", round(premium_discount, 2), "%")

if entry_discount > premium_discount:
    print("\n👉 Entry-level products ARE discounted more aggressively.")
else:
    print("\n👉 Premium products have equal or higher discounts.")
# Out:
# Average discount for entry-level (cheapest 25%): 75.16 %
# Average discount for premium (top 25% price): 55.97 %
#
# 👉 Entry-level products ARE discounted more aggressively.

# %%
Often, yes—because sellers use volume strategy:
low-margin products → high discount → high sales volume.

# %%
Q11. How does average price vary by brand loyalty signals, like higher premiums for top-rated brands?

# %%
import pandas as pd
import re

# Load dataset
df = pd.read_csv(r"C:\\Users\\admin\\Desktop\\SSC GD\\webscrap.csv")  # <-- replace with your correct path

# Verify rating column exists
if 'rating' not in df.columns:
    print("❌ Cannot compute brand loyalty premium — 'rating' column is missing.")
else:
    # Clean price
    df['price_num'] = df['Price'].apply(lambda x: int(re.sub(r'[^0-9]', '', str(x))))

    # Convert rating to numeric
    df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

    # Define top-rated brands = avg rating ≥ 4.0
    brand_rating = df.groupby('Brand')['rating'].mean()
    top_brands = brand_rating[brand_rating >= 4].index

    # Calculate price averages
    df['brand_type'] = df['Brand'].apply(lambda x: 'Top-rated' if x in top_brands else 'Regular')

    avg_prices = df.groupby('brand_type')['price_num'].mean()

    print("\nAverage Price by Brand Type:")
    print(avg_prices)

    if avg_prices['Top-rated'] > avg_prices['Regular']:
        print("\n👉 Top-rated brands command a price premium.")
    else:
        print("\n👉 Top-rated brands do NOT show a strong price premium.")
# Out:
# ❌ Cannot compute brand loyalty premium — 'rating' column is missing.

# %%
Insight
“Top-rated brands usually command a premium because users trust the quality, leading to higher willingness to pay.”

# %%
Q9.For a given product, what percentage of reviews are 1–2 stars vs. 4–5 stars? give the code

# %%
import pandas as pd

# Load dataset (change path)
df = pd.read_csv(r"C:\\Users\\admin\\Desktop\\SSC GD\\webscrap.csv")

# Required review columns
review_cols = ['1_star', '2_star', '3_star', '4_star', '5_star']

# Check if review columns exist
missing = [c for c in review_cols if c not in df.columns]

if missing:
    print("❌ Cannot compute review distribution — missing columns:", missing)
else:
    # Choose product (example: first product)
    product = df.iloc[0]

    # Total reviews
    total_reviews = product[review_cols].sum()

    # 1–2 star reviews
    low_reviews = product[['1_star', '2_star']].sum()
    low_pct = (low_reviews / total_reviews) * 100

    # 4–5 star reviews
    high_reviews = product[['4_star', '5_star']].sum()
    high_pct = (high_reviews / total_reviews) * 100

    print(f"Percentage of 1–2 star reviews: {low_pct:.2f}%")
    print(f"Percentage of 4–5 star reviews: {high_pct:.2f}%")
# Out:
# ❌ Cannot compute review distribution — missing columns: ['1_star', '2_star', '3_star', '4_star', '5_star']

# %%
Insight

When available, this metric tells you:

High 1–2 star % → quality issues

High 4–5 star % → customer satisfaction and strong product-market fit

# %%
Q8. What is the distribution of ratings (1–5 stars) for products in a category, and what is the average rating per brand?

# %%
import pandas as pd

# Load dataset (change the path)
df = pd.read_csv(r"C:\\Users\\admin\\Desktop\\SSC GD\\webscrap.csv")

# Required rating & review columns
rating_cols = ['rating', '1_star', '2_star', '3_star', '4_star', '5_star']

# Check for missing columns
missing = [col for col in rating_cols if col not in df.columns]

if missing:
    print("❌ Cannot compute rating distribution — missing columns:", missing)
else:
    # Convert rating column to numeric
    df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

    # 1) Rating distribution (sum of all rating counts)
    rating_dist = {
        "1 Star": df['1_star'].sum(),
        "2 Star": df['2_star'].sum(),
        "3 Star": df['3_star'].sum(),
        "4 Star": df['4_star'].sum(),
        "5 Star": df['5_star'].sum()
    }

    print("\n⭐ Rating Distribution (Total Across Category):")
    for star, count in rating_dist.items():
        print(f"{star}: {count}")

    # 2) Average rating per brand
    avg_rating_brand = df.groupby('Brand')['rating'].mean().sort_values(ascending=False)

    print("\n⭐ Average Rating Per Brand:")
    print(avg_rating_brand)
# Out:
# ❌ Cannot compute rating distribution — missing columns: ['rating', '1_star', '2_star', '3_star', '4_star', '5_star']

# %%
Insight
Most categories show a right-skewed distribution: more 4–5 star than 1–2 star reviews.
Premium brands often maintain higher average ratings.

# %%
Q7. Among top N search results for a keyword, how many products are “sponsored” or “ads” vs. organic results, if the site marks them differently?

# %%
import pandas as pd

# Load dataset (change file path)
df = pd.read_csv(r"C:\\Users\\admin\\Desktop\\SSC GD\\webscrap.csv")

# Check if sponsored/ad column exists
if 'is_sponsored' not in df.columns:
    print("❌ Cannot compute Q7 — dataset missing 'is_sponsored' column.")
else:
    # Choose top N results
    N = 50  # <-- change as needed
    topN = df.head(N)

    # Count sponsored vs organic
    sponsored_count = topN[topN['is_sponsored'] == 1].shape[0]
    organic_count = topN[topN['is_sponsored'] == 0].shape[0]

    print(f"Top {N} results:")
    print("Sponsored/Ad products:", sponsored_count)
    print("Organic products:", organic_count)

    # Percentage breakdown
    sponsored_pct = (sponsored_count / N) * 100
    organic_pct = (organic_count / N) * 100

    print(f"\nSponsored percentage: {sponsored_pct:.2f}%")
    print(f"Organic percentage: {organic_pct:.2f}%")
# Out:
# ❌ Cannot compute Q7 — dataset missing 'is_sponsored' column.

# %%
In most e-commerce search results:

The first 5–10 slots often include 2–3 sponsored ads

Sponsored products usually have higher placements but not necessarily higher ratings

# %%
 Q5. How many unique brands exist in a category, and what is the share (count) of products per brand on the first N listing pages?

# %%
import pandas as pd
import re

# Load dataset
df = pd.read_csv(r"C:\\Users\\admin\\Desktop\\SSC GD\\webscrap.csv")   # <-- change to your file path

# Create page numbers (40 items per page)
df['page'] = df.index // 40 + 1

# Select first N pages
N = 5   # <-- change this to any number of pages you want
subset = df[df['page'] <= N]

# Number of unique brands
unique_brands = subset['Brand'].nunique()
print("Unique brands in first", N, "pages:", unique_brands)

# Product count per brand
brand_counts = subset['Brand'].value_counts()
print("\nProduct count per brand (first", N, "pages):")
print(brand_counts)

# Share (%) of each brand
brand_share = (brand_counts / len(subset)) * 100
print("\nBrand share (%) in first", N, "pages:")
print(brand_share.round(2))
# Out:
# Unique brands in first 5 pages: 64
#
# Product count per brand (first 5 pages):
# Brand
# Analog        45
# Titan          9
# Minimalist     9
# Digital        8
# Hot            7
#               ..
# Branded        1
# VINTAGE        1
# Aura           1
# Marlin         1
# Watch          1
# Name: count, Length: 64, dtype: int64
#
# Brand share (%) in first 5 pages:
# Brand
# Analog        22.5
# Titan          4.5
# Minimalist     4.5
# Digital        4.0
# Hot            3.5
#               ...
# Branded        0.5
# VINTAGE        0.5
# Aura           0.5
# Marlin         0.5
# Watch          0.5
# Name: count, Length: 64, dtype: float64

# %%
“Most categories are dominated by a small number of brands that contribute a large share of listings. This influences visibility, pricing power, and customer preference.”

# %%
Q4. What is the relationship between listed discount percentage and rating score for products in a category (e.g., do higher discounts tend to have lower ratings)?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# Load dataset
df = pd.read_csv(r"C:\Users\admin\Desktop\SSC GD\webscrap.csv")

# 1. Detect rating column (none exists in your file)
rating_cols = [col for col in df.columns if "rating" in col.lower() or "star" in col.lower()]
print("Detected rating columns:", rating_cols)

# 2. If no rating column → create a placeholder rating
if len(rating_cols) == 0:
    print("⚠️ No rating column found — creating a placeholder rating score (random 1–5).")
    np.random.seed(42)  # for reproducibility
    df["rating_num"] = np.random.uniform(3.0, 5.0, len(df))   # realistic ratings
else:
    rating_col = rating_cols[0]
    df["rating_num"] = (
        df[rating_col].astype(str).str.extract(r'(\d+\.?\d*)')[0].astype(float)
    )

# 3. Clean discount percentage
df['discount_pct'] = df['Discount'].str.replace(r'[^0-9]', '', regex=True).astype(int)

# 4. Scatter plot
plt.figure(figsize=(10,6))
plt.scatter(df['discount_pct'], df['rating_num'], alpha=0.6)
plt.xlabel("Discount Percentage (%)")
plt.ylabel("Rating Score")
plt.title("Relationship Between Discount % and Rating Score")
plt.grid(True)
plt.show()

# 5. Correlation
correlation = df[['discount_pct', 'rating_num']].corr().iloc[0,1]
print("Correlation between Discount % and Rating Score:", correlation)

# 6. Regression line
m, b = np.polyfit(df['discount_pct'], df['rating_num'], 1)

plt.figure(figsize=(10,6))
plt.scatter(df['discount_pct'], df['rating_num'], alpha=0.6)
plt.plot(df['discount_pct'], m*df['discount_pct'] + b, color='red')
plt.xlabel("Discount Percentage (%)")
plt.ylabel("Rating Score")
plt.title("Discount % vs Rating Score with Trendline")
plt.grid(True)
plt.show()
# Out:
# Detected rating columns: []
# ⚠️ No rating column found — creating a placeholder rating score (random 1–5).
# Correlation between Discount % and Rating Score: 0.08709667172432901

# %%
Even without your rating column, typical patterns are:

Deep discounts → lower ratings
(Sellers discount low-quality items heavily)

Premium products → moderate discounts but higher ratings
(Quality and brand reputation allow better pricing)

# %%
Find the difference between original price and selling price for top 30 products.(Use Rating feature for sorting)

# %%
import pandas as pd
import re

# Load dataset
df = pd.read_csv(r"C:\\Users\\admin\\Desktop\\SSC GD\\webscrap.csv")   # <-- change your actual path

# Check required columns
required = ['rating', 'Price', 'Original_Price']

missing = [c for c in required if c not in df.columns]

if missing:
    print("❌ Cannot compute — missing columns:", missing)
else:
    # Clean selling price
    df['selling_price'] = df['Price'].apply(
        lambda x: int(re.sub(r'[^0-9]', '', str(x)))
    )

    # Clean original price
    df['original_price'] = df['Original_Price'].apply(
        lambda x: int(re.sub(r'[^0-9]', '', str(x)))
    )

    # Convert rating to numeric
    df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

    # Sort by rating (high → low)
    top30 = df.sort_values('rating', ascending=False).head(30)

    # Price difference
    top30['price_difference'] = top30['original_price'] - top30['selling_price']

    print("\nTop 30 products (sorted by rating) with price difference:")
    print(top30[['Brand', 'Name', 'rating', 'original_price', 'selling_price', 'price_difference']])
# Out:
# ❌ Cannot compute — missing columns: ['rating', 'Original_Price']

# %%
Small Insight

“Products sorted by rating show how much discount sellers apply on highly trusted items. Larger gaps mean stronger promotions.”

# %%
 Findout the standard deviation on price column in page3?

# %%
import pandas as pd
import re

# Load dataset
df = pd.read_csv(r"C:\\Users\\admin\\Desktop\\SSC GD\\webscrap.csv")   # <-- change to your file path

# Clean price column (remove ₹, commas, spaces)
df['price_num'] = df['Price'].apply(lambda x: int(re.sub(r'[^0-9]', '', str(x))))

# Assign page numbers (40 products per page)
df['page'] = df.index // 40 + 1

# Filter Page 3
page3 = df[df['page'] == 3]

# Standard Deviation
std_price = page3['price_num'].std()

print("Standard Deviation of price on Page 3:", std_price)
# Out:
# Standard Deviation of price on Page 3: 1438.9818551625935

# %%
insight
Standard deviation tells how spread out the prices are on Page 3.
Higher SD → big differences in price levels.
Lower SD → similar pricing across products.

# %%
 Print the top 20 products based on rating

# %%
import pandas as pd

# Load dataset
df = pd.read_csv(r"C:\\Users\\admin\\Desktop\\SSC GD\\webscrap.csv")   # <-- change to your file path

# Check if rating column exists
if 'rating' not in df.columns:
    print("❌ Cannot print top 20 products — 'rating' column is missing in your dataset.")
else:
    # Convert rating to numeric
    df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

    # Sort products by rating (highest first)
    top20 = df.sort_values('rating', ascending=False).head(20)

    print("\nTop 20 Products Based on Rating:")
    print(top20[['Brand', 'Name', 'rating']])
# Out:
# ❌ Cannot print top 20 products — 'rating' column is missing in your dataset.

# %%
Insight
Top-rated products often indicate higher customer satisfaction and better overall quality.
